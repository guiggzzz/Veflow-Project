# %%
import requests
import json
import pandas as pd

# %%
# Toutes les stations

api_key = "ba66e04fc0c6389242d8598aeee0906fe4b3d805"
url = f"https://api.jcdecaux.com/vls/v1/stations?contract=toulouse&apiKey={api_key}"
response = requests.get(url)
data = response.json()
data
# Out:
# [{'number': 55,
#   'contract_name': 'toulouse',
#   'name': '00055 - ST-SERNIN - GATIEN - ARNOULT',
#   'address': '2 RUE GATIEN ARNOULT',
#   'position': {'lat': 43.609022, 'lng': 1.441105},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 15,
#   'available_bike_stands': 8,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1759239624000},
#  {'number': 385,
#   'contract_name': 'toulouse',
#   'name': '00385 - VITARELLES - FRONDE',
#   'address': '21, chemin de la Fronde',
#   'position': {'lat': 43.587323, 'lng': 1.39462},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 7,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239614000},
#  {'number': 195,
#   'contract_name': 'toulouse',
#   'name': '00195 - RIEUX - CHANT DU MERLE',
#   'address': 'FACE 15 RUE PIERRE LAROUSSE',
#   'position': {'lat': 43.597355, 'lng': 1.459063},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 17,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239506000},
#  {'number': 29,
#   'contract_name': 'toulouse',
#   'name': '00029 - VALADE',
#   'address': '31 RUE VALADE',
#   'position': {'lat': 43.605031, 'lng': 1.437386},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 21,
#   'available_bike_stands': 17,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239579000},
#  {'number': 400,
#   'contract_name': 'toulouse',
#   'name': '00400 - SAINT-MARTIN-DU-TOUCH GARE',
#   'address': '4, rue Marie Louise Dissard (sur la contre allée face au parking de la halte)',
#   'position': {'lat': 43.600614, 'lng': 1.372218},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 6,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1759239122000},
#  {'number': 280,
#   'contract_name': 'toulouse',
#   'name': '00280 - CHARBONNIÈRE - PALMIERS',
#   'address': 'RUE DE LA CHARBONNIERE ENTRE IMP AMPERE ET RUE DES PALMIERS',
#   'position': {'lat': 43.573732, 'lng': 1.448768},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 18,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239336000},
#  {'number': 156,
#   'contract_name': 'toulouse',
#   'name': '00156 - EMPALOT - MÉTRO',
#   'address': '38 AV JEAN MOULIN FACE DEBOUCHE RUE DE CANNES',
#   'position': {'lat': 43.579666, 'lng': 1.44184},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 9,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1759239568000},
#  {'number': 242,
#   'contract_name': 'toulouse',
#   'name': '00242 - RIMBAUD - COLETTE / PADER - FRONTON',
#   'address': '8 RUE HILAIRE PADER',
#   'position': {'lat': 43.63639, 'lng': 1.433072},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 4,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1759239591000},
#  {'number': 373,
#   'contract_name': 'toulouse',
#   'name': '00373 - REYNERIE - LIZOP',
#   'address': '',
#   'position': {'lat': 43.566932, 'lng': 1.400526},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 5,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239537000},
#  {'number': 224,
#   'contract_name': 'toulouse',
#   'name': '00224 - BELIN - SUPAERO',
#   'address': "10 AV EDOUARD BELIN FACE CHATEAU D'EAU CREPS RD-PT JEAN LAGASSE",
#   'position': {'lat': 43.56644, 'lng': 1.475301},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 1,
#   'available_bikes': 19,
#   'status': 'OPEN',
#   'last_update': 1759239600000},
#  {'number': 339,
#   'contract_name': 'toulouse',
#   'name': '00339 -  GLOIRE - SAVIGNAC',
#   'address': '57, rue Labat de Savignac, 40m après angle rue de la Gloire',
#   'position': {'lat': 43.605899, 'lng': 1.463601},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 12,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239611000},
#  {'number': 229,
#   'contract_name': 'toulouse',
#   'name': '00229 - AV. DE RANGUEIL - PELUDE',
#   'address': '129 AV DE RANGUEIL',
#   'position': {'lat': 43.57141, 'lng': 1.462732},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 6,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1759239570000},
#  {'number': 154,
#   'contract_name': 'toulouse',
#   'name': '00154 - HOTEL DE REGION',
#   'address': '50 M AVANT 4 RUE DES GALLOIS',
#   'position': {'lat': 43.589928, 'lng': 1.441706},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 19,
#   'available_bike_stands': 7,
#   'available_bikes': 12,
#   'status': 'OPEN',
#   'last_update': 1759239596000},
#  {'number': 96,
#   'contract_name': 'toulouse',
#   'name': '00096 - MÉDIATHÈQUE JOSÉ CABANIS',
#   'address': '50 RUE DU GENERAL COMPANS',
#   'position': {'lat': 43.609757, 'lng': 1.455212},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 14,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1759239522000},
#  {'number': 65,
#   'contract_name': 'toulouse',
#   'name': '00065 - VERDIER - GRAND ROND',
#   'address': '2 ALL FORAIN FRANCOIS VERDIER',
#   'position': {'lat': 43.596904, 'lng': 1.452596},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 27,
#   'available_bike_stands': 24,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239632000},
#  {'number': 22,
#   'contract_name': 'toulouse',
#   'name': '00022 - CARNOT - ROLAND',
#   'address': '24 BD LAZARE CARNOT',
#   'position': {'lat': 43.602914, 'lng': 1.451719},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 13,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239597000},
#  {'number': 236,
#   'contract_name': 'toulouse',
#   'name': '00236 - TOEC - LEMIRE',
#   'address': "RUE DE L'ABBE JULES LEMIRE ANGLE VOIE DU TOEC",
#   'position': {'lat': 43.597322, 'lng': 1.403694},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 14,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239512000},
#  {'number': 315,
#   'contract_name': 'toulouse',
#   'name': '000315 - FRONTON - LAPIN',
#   'address': '269, Avenue de Fronton',
#   'position': {'lat': 43.651176, 'lng': 1.432557},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 10,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239621000},
#  {'number': 111,
#   'contract_name': 'toulouse',
#   'name': '00111 - BD DES MINIMES - PASSERELLE',
#   'address': '38B BD DES MINIMES',
#   'position': {'lat': 43.615273, 'lng': 1.442937},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 27,
#   'available_bike_stands': 23,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239625000},
#  {'number': 152,
#   'contract_name': 'toulouse',
#   'name': '00152 - THÉATRE DES MAZADES',
#   'address': '10 AV DES MAZADES',
#   'position': {'lat': 43.624114, 'lng': 1.438463},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 11,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239611000},
#  {'number': 243,
#   'contract_name': 'toulouse',
#   'name': '00243 - ÉTATS-UNIS - FERRY',
#   'address': 'FACE 97 AV DES ETATS-UNIS ANGLE JULES FERRY',
#   'position': {'lat': 43.632734, 'lng': 1.431732},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 17,
#   'available_bike_stands': 9,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239547000},
#  {'number': 384,
#   'contract_name': 'toulouse',
#   'name': '00384 GUILHERMY - LAS BRUGUES',
#   'address': '',
#   'position': {'lat': 43.567628, 'lng': 1.371151},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 8,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1759239555000},
#  {'number': 334,
#   'contract_name': 'toulouse',
#   'name': '00334  - GLOIRE - SAINT BERNARD',
#   'address': '1, rue Saint-Bertrand',
#   'position': {'lat': 43.605557, 'lng': 1.458483},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 9,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239631000},
#  {'number': 174,
#   'contract_name': 'toulouse',
#   'name': '00174 - BOURGES - MAUNOURY - MÉLAT',
#   'address': '41 AV MAURICE BOURGES MAUNOURY',
#   'position': {'lat': 43.63694, 'lng': 1.452615},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 19,
#   'available_bike_stands': 8,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1759239619000},
#  {'number': 298,
#   'contract_name': 'toulouse',
#   'name': '00298 - ROUTE DE SEYSSES - C. DE VICOSE',
#   'address': 'Route de Seysses - C. de Viçose',
#   'position': {'lat': 43.57179, 'lng': 1.418239},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 7,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239552000},
#  {'number': 276,
#   'contract_name': 'toulouse',
#   'name': '00276 - MARIN - REBOUL',
#   'address': 'FACE 1 CHEMIN DU MARIN',
#   'position': {'lat': 43.581463, 'lng': 1.379769},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 1,
#   'available_bikes': 17,
#   'status': 'OPEN',
#   'last_update': 1759239396000},
#  {'number': 77,
#   'contract_name': 'toulouse',
#   'name': '00077 - SAINT-CYPRIEN - METRO VIÉ',
#   'address': '2 PL INTERIEURE SAINT-CYPRIEN',
#   'position': {'lat': 43.59778, 'lng': 1.431619},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 0,
#   'available_bikes': 13,
#   'status': 'OPEN',
#   'last_update': 1759239550000},
#  {'number': 137,
#   'contract_name': 'toulouse',
#   'name': '00137 - BRUNHES - FONTAINES',
#   'address': '68 BD JEAN BRUNHES FACE AU 53',
#   'position': {'lat': 43.600473, 'lng': 1.420165},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 15,
#   'available_bike_stands': 14,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239590000},
#  {'number': 295,
#   'contract_name': 'toulouse',
#   'name': '00295 - PLACE GUY HERSANT',
#   'address': 'Place Guy Hersant, angle rue Alfred Rambaud',
#   'position': {'lat': 43.577461, 'lng': 1.442964},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 11,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239621000},
#  {'number': 348,
#   'contract_name': 'toulouse',
#   'name': '00348 - REVEL - LABEGE',
#   'address': ', Rond-point route de Revel / route de Labège face Jardiland et Midas,',
#   'position': {'lat': 43.570862, 'lng': 1.49832},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 5,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1759239625000},
#  {'number': 3002,
#   'contract_name': 'toulouse',
#   'name': '03002 - DOUMERGUE - DAUDET',
#   'address': 'Face 142, rue Gaston Doumergue - Tournefeuille',
#   'position': {'lat': 43.586113, 'lng': 1.352169},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 15,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239114000},
#  {'number': 144,
#   'contract_name': 'toulouse',
#   'name': '00144 - SUISSE - LAUSANNE',
#   'address': '62 BD DE SUISSE',
#   'position': {'lat': 43.615988, 'lng': 1.42163},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 22,
#   'available_bike_stands': 19,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239570000},
#  {'number': 5001,
#   'contract_name': 'toulouse',
#   'name': '05001 - RAMONVILLE MÉTRO',
#   'address': 'Avenue Flora Tristan sur le côté sud du bâtiment d’accès métro - Ramonville',
#   'position': {'lat': 43.55563, 'lng': 1.476132},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 0,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759233461000},
#  {'number': 40,
#   'contract_name': 'toulouse',
#   'name': '00040 - COLOMBETTE - MAURY',
#   'address': '41 RUE DE LA COLOMBETTE',
#   'position': {'lat': 43.604565, 'lng': 1.453659},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 15,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239626000},
#  {'number': 25,
#   'contract_name': 'toulouse',
#   'name': '00025 - PLACE ROUAIX',
#   'address': '1 RUE DES TOURNEURS',
#   'position': {'lat': 43.599525, 'lng': 1.445544},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 4,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1759239626000},
#  {'number': 74,
#   'contract_name': 'toulouse',
#   'name': '00074 - LAGANNE - TEINTURIERS',
#   'address': '37 RUE LAGANNE',
#   'position': {'lat': 43.596667, 'lng': 1.436229},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 15,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239565000},
#  {'number': 371,
#   'contract_name': 'toulouse',
#   'name': '00371 - REYNERIE - LONDRES',
#   'address': '9, rue de Londres',
#   'position': {'lat': 43.569148, 'lng': 1.408256},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 9,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239591000},
#  {'number': 71,
#   'contract_name': 'toulouse',
#   'name': '00071 - FER A CHEVAL - COURS DILLON',
#   'address': '3 RUE LAGANNE',
#   'position': {'lat': 43.593227, 'lng': 1.435062},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 22,
#   'available_bike_stands': 15,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239618000},
#  {'number': 329,
#   'contract_name': 'toulouse',
#   'name': '00329 - ATLANTA - CAUNES',
#   'address': 'Face dépot Tisséo sur avenue Atlanta',
#   'position': {'lat': 43.64046, 'lng': 1.469314},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 7,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1759239126000},
#  {'number': 64,
#   'contract_name': 'toulouse',
#   'name': '00064 - PERI - MERCADIER',
#   'address': '30 RUE GABRIEL PERI',
#   'position': {'lat': 43.606208, 'lng': 1.455005},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 24,
#   'available_bike_stands': 22,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239604000},
#  {'number': 3,
#   'contract_name': 'toulouse',
#   'name': '00003 - ALSACE - LORRAINE - POMME',
#   'address': '62 RUE DE LA POMME',
#   'position': {'lat': 43.603302, 'lng': 1.445454},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 4,
#   'available_bikes': 13,
#   'status': 'OPEN',
#   'last_update': 1759239610000},
#  {'number': 93,
#   'contract_name': 'toulouse',
#   'name': '00093 - BD MATABIAU - INGRES',
#   'address': '57 RUE DU PRINTEMPS',
#   'position': {'lat': 43.614574, 'lng': 1.443571},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 17,
#   'available_bike_stands': 12,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1759239539000},
#  {'number': 139,
#   'contract_name': 'toulouse',
#   'name': '00139 - BARRIERE DE LOMBEZ',
#   'address': '39 BIS AV DE LOMBEZ',
#   'position': {'lat': 43.595503, 'lng': 1.418503},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 3,
#   'available_bikes': 21,
#   'status': 'OPEN',
#   'last_update': 1759239504000},
#  {'number': 81,
#   'contract_name': 'toulouse',
#   'name': '00081 - JARDIN RAYMOND VI',
#   'address': 'ALLEE CHARLES DE FITTE / FACE JARDIN RAYMOND VI',
#   'position': {'lat': 43.599797, 'lng': 1.429521},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 33,
#   'available_bike_stands': 25,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1759239627000},
#  {'number': 60,
#   'contract_name': 'toulouse',
#   'name': '00060 - PLACE ROQUELAINE',
#   'address': '32 PL ROQUELAINE',
#   'position': {'lat': 43.612615, 'lng': 1.448286},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 24,
#   'available_bike_stands': 19,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239496000},
#  {'number': 36,
#   'contract_name': 'toulouse',
#   'name': '00036 - PLACE ROBERT SCHUMAN',
#   'address': '5 PL ROBERT SCHUMAN',
#   'position': {'lat': 43.609622, 'lng': 1.449431},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 19,
#   'available_bike_stands': 10,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1759239611000},
#  {'number': 227,
#   'contract_name': 'toulouse',
#   'name': '00227 - UNIV. PAUL SABATIER MÉTRO',
#   'address': '118  RTE DE NARBONNE',
#   'position': {'lat': 43.561074, 'lng': 1.462928},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 32,
#   'available_bike_stands': 0,
#   'available_bikes': 29,
#   'status': 'OPEN',
#   'last_update': 1759239522000},
#  {'number': 248,
#   'contract_name': 'toulouse',
#   'name': '00248 - ROSTAND - BOUQUETINS',
#   'address': 'RUE DES BOUQUETINS ANGLE RUE EDMOND ROSTAND',
#   'position': {'lat': 43.641013, 'lng': 1.448524},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 10,
#   'available_bikes': 10,
#   'status': 'OPEN',
#   'last_update': 1759239511000},
#  {'number': 53,
#   'contract_name': 'toulouse',
#   'name': '00053 - PLACE SAINT-JULIEN',
#   'address': 'PLACE SAINT JULIEN',
#   'position': {'lat': 43.608639, 'lng': 1.436965},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 20,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239608000},
#  {'number': 343,
#   'contract_name': 'toulouse',
#   'name': '00343 CHAUBET - CHIRAC',
#   'address': '',
#   'position': {'lat': 43.604681, 'lng': 1.474453},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 11,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239542000},
#  {'number': 379,
#   'contract_name': 'toulouse',
#   'name': '00379 - MAFFRE - BASSO CAMBO',
#   'address': 'Rue Robert Maffre, face 123, chemin de Basso Cambo',
#   'position': {'lat': 43.561453, 'lng': 1.384967},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 8,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1759239068000},
#  {'number': 187,
#   'contract_name': 'toulouse',
#   'name': '00187 - DESBALS - FIEUX',
#   'address': '187 RUE HENRI DESBALS',
#   'position': {'lat': 43.58456, 'lng': 1.415683},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 17,
#   'available_bike_stands': 2,
#   'available_bikes': 15,
#   'status': 'OPEN',
#   'last_update': 1759239504000},
#  {'number': 87,
#   'contract_name': 'toulouse',
#   'name': '00087 - LASCROSSES - LECLERC',
#   'address': '47 BD LASCROSSES',
#   'position': {'lat': 43.609277, 'lng': 1.432157},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 7,
#   'available_bikes': 16,
#   'status': 'OPEN',
#   'last_update': 1759239536000},
#  {'number': 358,
#   'contract_name': 'toulouse',
#   'name': '00358 - SALADE PONSAN - COTEAUX',
#   'address': '2, rue Thomas Edison',
#   'position': {'lat': 43.567744, 'lng': 1.451907},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 11,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239245000},
#  {'number': 346,
#   'contract_name': 'toulouse',
#   'name': "00346 - CITE DE L'ESPACE",
#   'address': 'Parking Cité de l’Espace le long de l’avenue Jean Gonord',
#   'position': {'lat': 43.586894, 'lng': 1.492386},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 2,
#   'available_bikes': 10,
#   'status': 'OPEN',
#   'last_update': 1759239043000},
#  {'number': 305,
#   'contract_name': 'toulouse',
#   'name': '00305 - ZENITH TRAMWAY',
#   'address': 'Face 151, avenue de Grande-Bretagne / Massonié',
#   'position': {'lat': 43.601356, 'lng': 1.411617},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 9,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239626000},
#  {'number': 225,
#   'contract_name': 'toulouse',
#   'name': '00225 - BELIN - ONERA',
#   'address': '4 AV EDOUARD BELIN DEVANT ONERA FACE AU CREPS',
#   'position': {'lat': 43.570117, 'lng': 1.473463},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 1,
#   'available_bikes': 19,
#   'status': 'OPEN',
#   'last_update': 1759239632000},
#  {'number': 397,
#   'contract_name': 'toulouse',
#   'name': '00397 - NÉGO SAOUMOS - ZIEGLER',
#   'address': '50m avant 5, rue Négo Saoumos',
#   'position': {'lat': 43.605637, 'lng': 1.364053},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 6,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1759239559000},
#  {'number': 381,
#   'contract_name': 'toulouse',
#   'name': '00381 - LIFFARD - REGUELONGUE',
#   'address': 'Liffard - Règuelongue',
#   'position': {'lat': 43.55978, 'lng': 1.37828},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 9,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239420000},
#  {'number': 121,
#   'contract_name': 'toulouse',
#   'name': '00121 - SERRES - ARNAUD BERNARD',
#   'address': '33 AV HONORE SERRES',
#   'position': {'lat': 43.612627, 'lng': 1.438268},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 17,
#   'available_bike_stands': 11,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239570000},
#  {'number': 84,
#   'contract_name': 'toulouse',
#   'name': '00084 - BRIENNE - MANUFACTURE',
#   'address': '19T ALL DE BRIENNE',
#   'position': {'lat': 43.605381, 'lng': 1.432485},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 24,
#   'available_bike_stands': 17,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1759239631000},
#  {'number': 208,
#   'contract_name': 'toulouse',
#   'name': '00208 - BAROUX - LIMAYRAC',
#   'address': 'Avenue Lucien Baroux, face parking Place Auguste Albert',
#   'position': {'lat': 43.591603, 'lng': 1.479018},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 17,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239408000},
#  {'number': 131,
#   'contract_name': 'toulouse',
#   'name': '00131 - ROUTE DE BLAGNAC - BERNIES',
#   'address': '15 RUE PAUL BERNIES',
#   'position': {'lat': 43.611584, 'lng': 1.414669},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 19,
#   'available_bike_stands': 15,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239451000},
#  {'number': 3004,
#   'contract_name': 'toulouse',
#   'name': '03004 - MONTEL - LANGUEDOC',
#   'address': 'Devant 17, boulevard Eugène Montel - Tournefeuille',
#   'position': {'lat': 43.585029, 'lng': 1.342821},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 13,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239133000},
#  {'number': 368,
#   'contract_name': 'toulouse',
#   'name': '00368 - ROUTE DE SEYSSES - BELLEFONTAINE',
#   'address': 'Face 10, allée Bellefontaine',
#   'position': {'lat': 43.562792, 'lng': 1.406829},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 11,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239584000},
#  {'number': 239,
#   'contract_name': 'toulouse',
#   'name': '00239 - LESPINET - HERBETTES',
#   'address': 'ANGLE AVENUE DE LESPINET ET RUE GEORGES BIDAULT',
#   'position': {'lat': 43.576637, 'lng': 1.470245},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 23,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239598000},
#  {'number': 1,
#   'contract_name': 'toulouse',
#   'name': "00001 - POIDS DE L'HUILE",
#   'address': "12 RUE DU POIDS DE L'HUILE",
#   'position': {'lat': 43.60419, 'lng': 1.445475},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 19,
#   'available_bike_stands': 1,
#   'available_bikes': 17,
#   'status': 'OPEN',
#   'last_update': 1759239613000},
#  {'number': 37,
#   'contract_name': 'toulouse',
#   'name': '00037 - STE - LUCIE - ARCS ST - CYPRIEN',
#   'address': '53 RUE SAINTE-LUCIE',
#   'position': {'lat': 43.593516, 'lng': 1.430039},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 11,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239622000},
#  {'number': 7,
#   'contract_name': 'toulouse',
#   'name': '00007 - PLACE VICTOR HUGO',
#   'address': '6 RUE DU REMPART VILLENEUVE',
#   'position': {'lat': 43.605777, 'lng': 1.446507},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 5,
#   'available_bikes': 20,
#   'status': 'OPEN',
#   'last_update': 1759239618000},
#  {'number': 259,
#   'contract_name': 'toulouse',
#   'name': '00259 - PLACE PAUL RICHÉ',
#   'address': 'PL PAUL RICHE A COTE 231 AV DE FRONTON',
#   'position': {'lat': 43.647504, 'lng': 1.43286},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 18,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239544000},
#  {'number': 367,
#   'contract_name': 'toulouse',
#   'name': '00367 - PARC DE GIRONIS',
#   'address': 'Parking salle des fêtes de Lafourguette',
#   'position': {'lat': 43.564067, 'lng': 1.413739},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 9,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239600000},
#  {'number': 304,
#   'contract_name': 'toulouse',
#   'name': '00304 - CARTOUCHERIE TRAMWAY',
#   'address': 'Place de la Charte des Libertes (le long du tram)',
#   'position': {'lat': 43.602797, 'lng': 1.408133},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 1,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1759239628000},
#  {'number': 297,
#   'contract_name': 'toulouse',
#   'name': '00297 - AV. DE MURET - DUBOUL',
#   'address': '3, rue Axel Duboul - Carrefour avenue de Muret',
#   'position': {'lat': 43.57981, 'lng': 1.4237},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 3,
#   'available_bikes': 9,
#   'status': 'OPEN',
#   'last_update': 1759239632000},
#  {'number': 234,
#   'contract_name': 'toulouse',
#   'name': '00234 - RAYNAL - LOUIN',
#   'address': '50M APRES 4 RUE PIERRETTE LOUIN',
#   'position': {'lat': 43.628145, 'lng': 1.451413},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 15,
#   'available_bike_stands': 11,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239601000},
#  {'number': 192,
#   'contract_name': 'toulouse',
#   'name': '00192 - RE DE ST - SIMON - PRADO',
#   'address': '355 ROUTE DE SAINT-SIMON',
#   'position': {'lat': 43.587845, 'lng': 1.409785},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 13,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239446000},
#  {'number': 48,
#   'contract_name': 'toulouse',
#   'name': '00048 - PLACE DU SALIN',
#   'address': '18 PL DU SALIN',
#   'position': {'lat': 43.594461, 'lng': 1.443822},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 32,
#   'available_bike_stands': 22,
#   'available_bikes': 9,
#   'status': 'OPEN',
#   'last_update': 1759239545000},
#  {'number': 175,
#   'contract_name': 'toulouse',
#   'name': '00175 - BORDEROUGE - MÉTRO',
#   'address': 'FACE 52 AV BOURGES MAUNOURY',
#   'position': {'lat': 43.639633, 'lng': 1.452569},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 20,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1759239623000},
#  {'number': 266,
#   'contract_name': 'toulouse',
#   'name': '00266 - TOURAINE - AUVERGNE',
#   'address': '38 RUE DE LA TOURAINE',
#   'position': {'lat': 43.573708, 'lng': 1.41394},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 14,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239589000},
#  {'number': 386,
#   'contract_name': 'toulouse',
#   'name': '00386 - BORDEBLANCHE - BROUSSIN',
#   'address': '16, chemin de Bordeblanche',
#   'position': {'lat': 43.582717, 'lng': 1.386115},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 8,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239094000},
#  {'number': 166,
#   'contract_name': 'toulouse',
#   'name': '00166 - RANGUEIL - MÉTRO',
#   'address': '23 RUE GUYOU',
#   'position': {'lat': 43.57421, 'lng': 1.462367},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 3,
#   'available_bikes': 15,
#   'status': 'OPEN',
#   'last_update': 1759239525000},
#  {'number': 135,
#   'contract_name': 'toulouse',
#   'name': '00135 - BONNEFOY - LEMAITRE',
#   'address': '179 RUE DU FAUBOURG BONNEFOY',
#   'position': {'lat': 43.622963, 'lng': 1.458647},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 8,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1759239622000},
#  {'number': 79,
#   'contract_name': 'toulouse',
#   'name': '00079 - VIGUERIE -  LANGE',
#   'address': '1 PL LANGE',
#   'position': {'lat': 43.601016, 'lng': 1.434129},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 9,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1759239622000},
#  {'number': 210,
#   'contract_name': 'toulouse',
#   'name': '00210 - TERRASSE - MONT VENTOUX',
#   'address': 'FACE 42 CHE DE LA TERRASSE',
#   'position': {'lat': 43.586086, 'lng': 1.482942},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 16,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239283000},
#  {'number': 75,
#   'contract_name': 'toulouse',
#   'name': "00075 - CHATEAU D'EAU",
#   'address': '12 PLACE LAGANNE',
#   'position': {'lat': 43.59859, 'lng': 1.436594},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 21,
#   'available_bike_stands': 12,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759225278000},
#  {'number': 5004,
#   'contract_name': 'toulouse',
#   'name': '05004 - POMPIDOU - MARNAC',
#   'address': 'Face 9, allée Georges Pompidou - Ramonville',
#   'position': {'lat': 43.548859, 'lng': 1.477414},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 4,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239398000},
#  {'number': 1031,
#   'contract_name': 'toulouse',
#   'name': '1031 - BORNE CGB ATELIER',
#   'address': '16 rue Brouardel',
#   'position': {'lat': 43.6159088, 'lng': 1.0001755},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 12,
#   'available_bike_stands': 5,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239569000},
#  {'number': 115,
#   'contract_name': 'toulouse',
#   'name': '00115 - DUMERIL - SAINT JOSEPH',
#   'address': 'FACE 104 RUE ALFRED DUMERIL',
#   'position': {'lat': 43.591224, 'lng': 1.452159},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 6,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1759239634000},
#  {'number': 221,
#   'contract_name': 'toulouse',
#   'name': '00221 - AV. DE REYNERIE - VAUQUELIN',
#   'address': 'FACE 85 RUE VAUQUELIN',
#   'position': {'lat': 43.576221, 'lng': 1.406355},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 1,
#   'available_bikes': 19,
#   'status': 'OPEN',
#   'last_update': 1759239612000},
#  {'number': 294,
#   'contract_name': 'toulouse',
#   'name': '00294 - ILE DU RAMIER - PASSERELLE CONTI',
#   'address': 'ILE DU RAMIER - PASSERELLE CONTI',
#   'position': {'lat': 43.580259, 'lng': 1.434156},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 11,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239599000},
#  {'number': 128,
#   'contract_name': 'toulouse',
#   'name': '00128 - SAINT-MICHEL - CASTELET',
#   'address': '18 B GRANDE RUE ST MICHEL',
#   'position': {'lat': 43.58585, 'lng': 1.447374},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 24,
#   'available_bike_stands': 20,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239604000},
#  {'number': 375,
#   'contract_name': 'toulouse',
#   'name': '00375 - LESTAND - PERGAUD',
#   'address': '32, chemin de Lestang – passage Louis Pergaud',
#   'position': {'lat': 43.564715, 'lng': 1.395886},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 6,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1759239624000},
#  {'number': 67,
#   'contract_name': 'toulouse',
#   'name': '00067 - GUESDE - OZENNE',
#   'address': '35 ALL JULES GUESDE',
#   'position': {'lat': 43.594812, 'lng': 1.449176},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 22,
#   'available_bike_stands': 8,
#   'available_bikes': 13,
#   'status': 'OPEN',
#   'last_update': 1759239570000},
#  {'number': 1002,
#   'contract_name': 'toulouse',
#   'name': '01002 - FRONTON - ALLENDE',
#   'address': 'Avenue Salvador Allende – parking face restaurant «\xa0la côte et l’arête\xa0» - Aucamville',
#   'position': {'lat': 43.661581, 'lng': 1.43105},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 8,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1759239519000},
#  {'number': 188,
#   'contract_name': 'toulouse',
#   'name': '00188 - AV. DE MURET - LAFAGE',
#   'address': '121 AVENUE DE MURET',
#   'position': {'lat': 43.584339, 'lng': 1.427597},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 12,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1759239606000},
#  {'number': 118,
#   'contract_name': 'toulouse',
#   'name': '00118 - PLACE DU BUSCA',
#   'address': 'PLACE DU BUSCA / FACE ECOLE JEAN JAURES',
#   'position': {'lat': 43.588588, 'lng': 1.451003},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 9,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239632000},
#  {'number': 354,
#   'contract_name': 'toulouse',
#   'name': '00354 - DAURAT - CORNEMONT',
#   'address': '2, rue René Cornemont - Face rond-point Henri Erable',
#   'position': {'lat': 43.56481, 'lng': 1.488996},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 10,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239596000},
#  {'number': 178,
#   'contract_name': 'toulouse',
#   'name': '00178 - BRUNAUD - PLANA',
#   'address': 'FACE 100 AV YVES BRUNAUD',
#   'position': {'lat': 43.619291, 'lng': 1.468681},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 19,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239431000},
#  {'number': 341,
#   'contract_name': 'toulouse',
#   'name': '00341 - SOUPETARD - GENÊTS',
#   'address': '42, rue Soupetard',
#   'position': {'lat': 43.610183, 'lng': 1.472401},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 12,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239419000},
#  {'number': 41,
#   'contract_name': 'toulouse',
#   'name': '00041 - RIQUET - CAMICHEL',
#   'address': '1 RUE CHARLES CAMICHEL',
#   'position': {'lat': 43.602708, 'lng': 1.454367},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 21,
#   'available_bike_stands': 13,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239631000},
#  {'number': 90,
#   'contract_name': 'toulouse',
#   'name': '00090 - LASCROSSES - ARNAUD BERNARD',
#   'address': '3B BD LASCROSSES',
#   'position': {'lat': 43.611271, 'lng': 1.438093},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 19,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239532000},
#  {'number': 68,
#   'contract_name': 'toulouse',
#   'name': '00068  PALAIS DE JUSTICE - METRO',
#   'address': '1 BIS ALLEE JULES GUESDE',
#   'position': {'lat': 43.592782, 'lng': 1.444726},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 7,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239628000},
#  {'number': 147,
#   'contract_name': 'toulouse',
#   'name': '00147 - CHAUSSAS - DAUDET',
#   'address': '96 RUE DE CHAUSSAS',
#   'position': {'lat': 43.619704, 'lng': 1.429176},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 19,
#   'available_bike_stands': 17,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239552000},
#  {'number': 406,
#   'contract_name': 'toulouse',
#   'name': '00406 - LARDENNE - MAXWELL',
#   'address': 'Face 343, avenue de Lardenne et du groupe scolaire Emilie Chatelet',
#   'position': {'lat': 43.590272, 'lng': 1.367674},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 10,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239431000},
#  {'number': 109,
#   'contract_name': 'toulouse',
#   'name': '00109 - HOTEL DE DÉPARTEMENT',
#   'address': '1 BD DE LA MARQUETTE',
#   'position': {'lat': 43.615275, 'lng': 1.434944},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 19,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239490000},
#  {'number': 2007,
#   'contract_name': 'toulouse',
#   'name': '02007 - BLAGNAC MAIRIE',
#   'address': 'Place Jean-Louis Puig, face mairie - Blagnac',
#   'position': {'lat': 43.634559, 'lng': 1.397157},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 15,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239039000},
#  {'number': 153,
#   'contract_name': 'toulouse',
#   'name': '00153 - PLACE ANTONIN FROIDURE',
#   'address': '12 AV BOURGES MAUNOURY',
#   'position': {'lat': 43.628672, 'lng': 1.448469},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 12,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239543000},
#  {'number': 390,
#   'contract_name': 'toulouse',
#   'name': '00390 - CAPELLES - ECOLE VETERINAIRE',
#   'address': '',
#   'position': {'lat': 43.601523, 'lng': 1.384712},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 7,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239498000},
#  {'number': 262,
#   'contract_name': 'toulouse',
#   'name': '00262 - ARTHAUD - NETWILLER',
#   'address': 'RON?D-POINT NETWILLER - BORDEROUGE',
#   'position': {'lat': 43.643358, 'lng': 1.455501},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 11,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1759239444000},
#  {'number': 399,
#   'contract_name': 'toulouse',
#   'name': '00399 - CHEMIN DE TOURNEFEUILLE - BOURIETTE',
#   'address': 'Parking, 212 chemin de Tournefeuille',
#   'position': {'lat': 43.605078, 'lng': 1.376499},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 7,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239499000},
#  {'number': 197,
#   'contract_name': 'toulouse',
#   'name': '00197 - PUJOL - PÉRIGNON',
#   'address': '6 AV LOUIS BLERIOT',
#   'position': {'lat': 43.600361, 'lng': 1.464039},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 19,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239633000},
#  {'number': 336,
#   'contract_name': 'toulouse',
#   'name': '00336 - COLONNE - SALONIQUE',
#   'address': 'Face 90, avenue de la Colonne, 30 m après angle rue de Caillibens',
#   'position': {'lat': 43.610556, 'lng': 1.464953},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 8,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239421000},
#  {'number': 388,
#   'contract_name': 'toulouse',
#   'name': '00388 - LARDENNE - CALQUET',
#   'address': 'Face au 145, avenue de Lardenne / Chemin de Calquet',
#   'position': {'lat': 43.5937364, 'lng': 1.3911254},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 11,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239463000},
#  {'number': 23,
#   'contract_name': 'toulouse',
#   'name': '00023 - CARNOT - IDRAC',
#   'address': '6 BD LAZARE CARNOT',
#   'position': {'lat': 43.601372, 'lng': 1.452038},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 26,
#   'available_bike_stands': 25,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239463000},
#  {'number': 396,
#   'contract_name': 'toulouse',
#   'name': '00396 - FOURNIER - JARDINERIE',
#   'address': 'Rue Alain Fournier',
#   'position': {'lat': 43.606486, 'lng': 1.36915},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 8,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1759239406000},
#  {'number': 183,
#   'contract_name': 'toulouse',
#   'name': '00183 - RUE DE CUGNAUX - GRAVETTE',
#   'address': 'RUE DE CUGNAUX',
#   'position': {'lat': 43.593147, 'lng': 1.424313},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 12,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1759239574000},
#  {'number': 376,
#   'contract_name': 'toulouse',
#   'name': '00376 - EISENHOWER - LESTANG',
#   'address': 'Avenue du général Eisenhower, face au collège Saint Simon',
#   'position': {'lat': 43.5599624, 'lng': 1.3944267},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 9,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239432000},
#  {'number': 338,
#   'contract_name': 'toulouse',
#   'name': '00338 - GUILLAUMET - CEAT',
#   'address': 'Face 24, avenue Henri Guillaumet (nouveau quartier)',
#   'position': {'lat': 43.61445, 'lng': 1.469636},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 6,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239173000},
#  {'number': 126,
#   'contract_name': 'toulouse',
#   'name': '00126 - BONNEFOY - ARAGO',
#   'address': '18 RUE BONNEFOY',
#   'position': {'lat': 43.616939, 'lng': 1.454243},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 22,
#   'available_bike_stands': 13,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1759239522000},
#  {'number': 255,
#   'contract_name': 'toulouse',
#   'name': '00255 - SELLIER - MOUETTES',
#   'address': '2 RUE DES MOUETTES / ANGLE ALL HENRI SELLIER',
#   'position': {'lat': 43.576893, 'lng': 1.440049},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 10,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1759239624000},
#  {'number': 233,
#   'contract_name': 'toulouse',
#   'name': '00233 - NARBONNE - SAHUQUE',
#   'address': 'FACE 88 RTE DE NARBONNE STATION ESSO',
#   'position': {'lat': 43.566528, 'lng': 1.458648},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 16,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239543000},
#  {'number': 254,
#   'contract_name': 'toulouse',
#   'name': '00254 - VESTREPAIN - LOT',
#   'address': 'RUE DU LOT / 100M AVANT LA RUE VESTREPAIN',
#   'position': {'lat': 43.583264, 'lng': 1.407055},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 6,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1759239606000},
#  {'number': 21,
#   'contract_name': 'toulouse',
#   'name': '00021 - CARNOT - LABEDA',
#   'address': '63 BD LAZARE CARNOT',
#   'position': {'lat': 43.604079, 'lng': 1.450158},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 23,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239584000},
#  {'number': 62,
#   'contract_name': 'toulouse',
#   'name': '00062 - JAURES - BONREPOS',
#   'address': '81 ALLEE JEAN JAURES',
#   'position': {'lat': 43.609222, 'lng': 1.453542},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 24,
#   'available_bike_stands': 22,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239445000},
#  {'number': 370,
#   'contract_name': 'toulouse',
#   'name': '00370 - PLACE DES TIBAOUS',
#   'address': 'Face 11 et 13, rue Missak Manouchian',
#   'position': {'lat': 43.550424, 'lng': 1.386158},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 5,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1759239362000},
#  {'number': 244,
#   'contract_name': 'toulouse',
#   'name': '00244 - RENAN - VITRY',
#   'address': '93 RUE ERNEST RENAN ANGLE RUE VITRY',
#   'position': {'lat': 43.635856, 'lng': 1.443828},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 15,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239559000},
#  {'number': 24,
#   'contract_name': 'toulouse',
#   'name': '00024 - PLACE SAINT-ETIENNE',
#   'address': '14 PL SAINT-ETIENNE',
#   'position': {'lat': 43.600055, 'lng': 1.449273},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 22,
#   'available_bike_stands': 7,
#   'available_bikes': 14,
#   'status': 'OPEN',
#   'last_update': 1759239616000},
#  {'number': 245,
#   'contract_name': 'toulouse',
#   'name': '00245 - GRANDE-BRETAGNE - BADIOU',
#   'address': '103 BIS AV DE GRANDE BRETAGNE ANGLE RUE BADIOU',
#   'position': {'lat': 43.599732, 'lng': 1.415372},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 19,
#   'available_bike_stands': 17,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239631000},
#  {'number': 196,
#   'contract_name': 'toulouse',
#   'name': '00196 - PUJOL - GOUJON',
#   'address': '6 RUE JEAN GOUJON',
#   'position': {'lat': 43.601719, 'lng': 1.458019},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 18,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239624000},
#  {'number': 281,
#   'contract_name': 'toulouse',
#   'name': '00281 - JARDIN NIEL',
#   'address': "FACE 80 RUE SAINT ROCH / ANGLE AC DU 14EME REGIMENT D'INFANTERIE",
#   'position': {'lat': 43.578687, 'lng': 1.446733},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 14,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239480000},
#  {'number': 260,
#   'contract_name': 'toulouse',
#   'name': '00260 - FRONTON - DUCLOS',
#   'address': 'RUE LEONCE DUCLOS / ANGLE AV DE FRONTON FACE 26 IMP DU BARON',
#   'position': {'lat': 43.644963, 'lng': 1.433998},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 12,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239178000},
#  {'number': 228,
#   'contract_name': 'toulouse',
#   'name': '00228 - FAC. DE PHARMACIE MÉTRO',
#   'address': 'FACE 35 CHEMIN DES MARAICHERS',
#   'position': {'lat': 43.568165, 'lng': 1.464353},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 6,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1759239556000},
#  {'number': 124,
#   'contract_name': 'toulouse',
#   'name': '00124 - EGLISE DES MINIMES',
#   'address': '27 AV DES MINIMES',
#   'position': {'lat': 43.618287, 'lng': 1.436857},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 14,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239595000},
#  {'number': 207,
#   'contract_name': 'toulouse',
#   'name': '00207 - MAL CLABEL - AUDE',
#   'address': 'FACE 25 RUE DE L AUDE',
#   'position': {'lat': 43.583202, 'lng': 1.481757},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 17,
#   'available_bike_stands': 15,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239533000},
#  {'number': 11,
#   'contract_name': 'toulouse',
#   'name': '00011 - PLACE DE LA DAURADE',
#   'address': '2 PL DE LA DAURADE',
#   'position': {'lat': 43.601888, 'lng': 1.440368},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 23,
#   'available_bike_stands': 11,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1759239625000},
#  {'number': 319,
#   'contract_name': 'toulouse',
#   'name': '00319 - ROUTE DE LAUNAGUET - DELBO',
#   'address': 'Rond-point, 50m avant 283, route de Launaguet',
#   'position': {'lat': 43.651318, 'lng': 1.438377},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 5,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1759239079000},
#  {'number': 186,
#   'contract_name': 'toulouse',
#   'name': '00186 - DESBALS - BOUALAM',
#   'address': '1 IMPASSE BACHAGA BOUALAM',
#   'position': {'lat': 43.579171, 'lng': 1.410939},
#   'banking': False,
# ...
#  {'number': 43,
#   'contract_name': 'toulouse',
#   'name': '00043 - PLACE DUPUY',
#   'address': '14 PL DOMINIQUE MARTIN DUPUY',
#   'position': {'lat': 43.600188, 'lng': 1.454764},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 22,
#   'available_bike_stands': 18,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239539000},
#  {'number': 408,
#   'contract_name': 'toulouse',
#   'name': '00408 - BRUNAUD - CEAT',
#   'address': 'Face 76, avenue Yves Brunaud - Toulouse',
#   'position': {'lat': 43.617615, 'lng': 1.466289},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 11,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239104000},
#  {'number': 232,
#   'contract_name': 'toulouse',
#   'name': '00232 - NARBONNE - CAUBERE',
#   'address': '73 RTE DE NARBONNE',
#   'position': {'lat': 43.569089, 'lng': 1.456292},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 15,
#   'available_bike_stands': 11,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239531000},
#  {'number': 61,
#   'contract_name': 'toulouse',
#   'name': '00061 - MATABIAU GARE - BONREPOS',
#   'address': '12 BD DE BONREPOS',
#   'position': {'lat': 43.611052, 'lng': 1.452593},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 26,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1759239606000},
#  {'number': 378,
#   'contract_name': 'toulouse',
#   'name': '00378 - BASSO CAMBO METRO',
#   'address': 'P+R Métro Basso, entre Parc à vélo et parking aérien',
#   'position': {'lat': 43.569972, 'lng': 1.391809},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 4,
#   'available_bikes': 9,
#   'status': 'OPEN',
#   'last_update': 1759239426000},
#  {'number': 211,
#   'contract_name': 'toulouse',
#   'name': '00211 - LA TERRASSE - LEDORMEUR',
#   'address': '9 RUE LE DORMEUR',
#   'position': {'lat': 43.583511, 'lng': 1.487795},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 15,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239379000},
#  {'number': 165,
#   'contract_name': 'toulouse',
#   'name': '00165 -  AVIONS - LIBELLULES',
#   'address': '33 AVENUE DES AVIONS',
#   'position': {'lat': 43.57688, 'lng': 1.460189},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 15,
#   'available_bike_stands': 3,
#   'available_bikes': 12,
#   'status': 'OPEN',
#   'last_update': 1759239628000},
#  {'number': 393,
#   'contract_name': 'toulouse',
#   'name': '00393 - HOPITAL PURPAN',
#   'address': 'Avenue du Professeur Jean Dausset – carrefour Tram / entrée de l’hôpital Paule de Viguier',
#   'position': {'lat': 43.60768, 'lng': 1.402173},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 10,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239537000},
#  {'number': 278,
#   'contract_name': 'toulouse',
#   'name': '00278 - ARÈNES ROMAINES TRAMWAY',
#   'address': 'RD PT ANGLE AV DES ARENES ROMAINES RUE JEAN ESPITALIER',
#   'position': {'lat': 43.614159, 'lng': 1.397008},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 16,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239542000},
#  {'number': 270,
#   'contract_name': 'toulouse',
#   'name': '00270 - TRENTIN - VERNE',
#   'address': 'RUE JULES VERNE / ANGLE FACE 40 BD SILVIO TRENTIN',
#   'position': {'lat': 43.623998, 'lng': 1.427823},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 12,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239615000},
#  {'number': 103,
#   'contract_name': 'toulouse',
#   'name': '00103 - ST - MICHEL - STE - CATHERINE',
#   'address': '134 GRANDE RUE SAINT-MICHEL',
#   'position': {'lat': 43.590847, 'lng': 1.445284},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 14,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239600000},
#  {'number': 307,
#   'contract_name': 'toulouse',
#   'name': '00307 - SUISSE - POLITKOVSKAIA',
#   'address': '38, boulevard de Suisse',
#   'position': {'lat': 43.61324, 'lng': 1.419932},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 12,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239600000},
#  {'number': 17,
#   'contract_name': 'toulouse',
#   'name': '00017 - STRASBOURG - AUSTERLITZ',
#   'address': '7 BD DE STRASBOURG',
#   'position': {'lat': 43.606499, 'lng': 1.44769},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 23,
#   'available_bike_stands': 2,
#   'available_bikes': 21,
#   'status': 'OPEN',
#   'last_update': 1759239548000},
#  {'number': 326,
#   'contract_name': 'toulouse',
#   'name': '00326 - EBELOT - PUJIBET',
#   'address': 'Face 55, rue Henri Ebelot (sur le rond-point)',
#   'position': {'lat': 43.638044, 'lng': 1.457716},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 3,
#   'available_bikes': 9,
#   'status': 'OPEN',
#   'last_update': 1759239606000},
#  {'number': 2012,
#   'contract_name': 'toulouse',
#   'name': '02012 - PLACE GEORGES BRASSENS',
#   'address': 'Parking, face écoles Louis Weidknnet - Place Georges Brassens - Blagnac',
#   'position': {'lat': 43.64883, 'lng': 1.376338},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 15,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1759239584000},
#  {'number': 46,
#   'contract_name': 'toulouse',
#   'name': '00046 - PLACE DES CARMES',
#   'address': '1 PL DES CARMES',
#   'position': {'lat': 43.597364, 'lng': 1.445314},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 14,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1759239347000},
#  {'number': 218,
#   'contract_name': 'toulouse',
#   'name': '00218 - AMOUROUX - STE - AUGUSTINE',
#   'address': '24 BIS CHE AMOUROUX',
#   'position': {'lat': 43.627643, 'lng': 1.461861},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 14,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239590000},
#  {'number': 203,
#   'contract_name': 'toulouse',
#   'name': '00203 - ST-EXUPERY - PETIT PRINCE',
#   'address': '2 AV ANTOINE DE ST EXUPERY',
#   'position': {'lat': 43.58355, 'lng': 1.470033},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 14,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239616000},
#  {'number': 2014,
#   'contract_name': 'toulouse',
#   'name': '02014 - AV. DU PARC - GUYENNE',
#   'address': 'Av. du Parc - Guyenne',
#   'position': {'lat': 43.632311, 'lng': 1.388446},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 15,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239593000},
#  {'number': 311,
#   'contract_name': 'toulouse',
#   'name': '00311 - ETATS-UNIS - GLACIÈRE',
#   'address': 'Face 67, rue de la Glacière - carrefour rue de la Glacière / avenue des Etats-Unis',
#   'position': {'lat': 43.646471, 'lng': 1.426013},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 2,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1759239576000},
#  {'number': 387,
#   'contract_name': 'toulouse',
#   'name': '00387 - CORIOLIS - DUPOUY',
#   'address': 'Avenue Gaspard Coriolis carrefour rue du professeur Gaston Dupouy',
#   'position': {'lat': 43.578809, 'lng': 1.379975},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 0,
#   'available_bikes': 13,
#   'status': 'OPEN',
#   'last_update': 1759239584000},
#  {'number': 296,
#   'contract_name': 'toulouse',
#   'name': '00296 - ESPAGNE-LANGLADE',
#   'address': "89, route d'Espagne",
#   'position': {'lat': 43.571858, 'lng': 1.42447},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 4,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239632000},
#  {'number': 132,
#   'contract_name': 'toulouse',
#   'name': '00132 - MINIMES - BAQUÉ',
#   'address': '101 AVENUES DES MINIMES',
#   'position': {'lat': 43.622966, 'lng': 1.434449},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 19,
#   'available_bike_stands': 12,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239464000},
#  {'number': 145,
#   'contract_name': 'toulouse',
#   'name': '00145 - GOUNOD - GARROS',
#   'address': '29 RUE ROLAND GARROS',
#   'position': {'lat': 43.613881, 'lng': 1.424953},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 18,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239625000},
#  {'number': 32,
#   'contract_name': 'toulouse',
#   'name': '00032 - MUSEE SAINT-RAYMOND',
#   'address': '2 PLACE SAINT-SERNIN / ANGLE 2 RUE DES 3 RENARDS',
#   'position': {'lat': 43.607608, 'lng': 1.441304},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 12,
#   'available_bike_stands': 7,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239533000},
#  {'number': 374,
#   'contract_name': 'toulouse',
#   'name': '00374 - BELLEFONTAINE MÉTRO',
#   'address': 'Allée de Bellefontaine',
#   'position': {'lat': 43.565832, 'lng': 1.398708},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 3,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239597000},
#  {'number': 5,
#   'contract_name': 'toulouse',
#   'name': '00005 - MARENGO - LEDUC',
#   'address': 'FACE AU 5 RUE RENE LEDUC',
#   'position': {'lat': 43.611386, 'lng': 1.456729},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 19,
#   'available_bike_stands': 17,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239627000},
#  {'number': 289,
#   'contract_name': 'toulouse',
#   'name': '00289 - BIARRITZ - CASSELARDIT',
#   'address': '18, avenue de Biarritz',
#   'position': {'lat': 43.607189, 'lng': 1.409324},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 5,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1759239302000},
#  {'number': 110,
#   'contract_name': 'toulouse',
#   'name': '00110 - SERRES - CABANEL',
#   'address': '16 RUE ALEXANDRE CABANEL',
#   'position': {'lat': 43.614227, 'lng': 1.437999},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 15,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1759239522000},
#  {'number': 125,
#   'contract_name': 'toulouse',
#   'name': '00125 - BARRIERE DE PARIS MÉTRO',
#   'address': 'FACE AU 2 BARRIERE DE PARIS',
#   'position': {'lat': 43.627017, 'lng': 1.434129},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 19,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1759239606000},
#  {'number': 63,
#   'contract_name': 'toulouse',
#   'name': '00063 - PISCINE LEO LAGRANGE',
#   'address': '54 RUE DES SEPT TROUBADOURS',
#   'position': {'lat': 43.607468, 'lng': 1.454329},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 22,
#   'available_bike_stands': 10,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1759239507000},
#  {'number': 4002,
#   'contract_name': 'toulouse',
#   'name': '04002 - LABÈGE INNOPOLE GARE',
#   'address': 'Parking proche gare SNCF Innopole et Parc à vélo - Labège',
#   'position': {'lat': 43.547467, 'lng': 1.51246},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 13,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239081000},
#  {'number': 177,
#   'contract_name': 'toulouse',
#   'name': '00177 - BRUNAUD - BAILLAUD',
#   'address': '64 RUE BAILLAUD',
#   'position': {'lat': 43.617458, 'lng': 1.465428},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 14,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1759239467000},
#  {'number': 73,
#   'contract_name': 'toulouse',
#   'name': '00073 - FITTE - TEINTURIERS',
#   'address': '40 ALLEE CHARLES DE FITTE',
#   'position': {'lat': 43.596294, 'lng': 1.432158},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 6,
#   'available_bikes': 10,
#   'status': 'OPEN',
#   'last_update': 1759239538000},
#  {'number': 364,
#   'contract_name': 'toulouse',
#   'name': '00364 - ESPAGNE - GIRONIS',
#   'address': 'Rond-point Hélène Rouch – route d’Espagne face clinique Médipôle',
#   'position': {'lat': 43.563741, 'lng': 1.425433},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 13,
#   'available_bike_stands': 4,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1759239595000},
#  {'number': 200,
#   'contract_name': 'toulouse',
#   'name': '00200 - REVEL - BAJAC',
#   'address': '43 route de Revel - Gymnase écoles publiques Henri Guillaumet',
#   'position': {'lat': 43.576559, 'lng': 1.487548},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 15,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239558000},
#  {'number': 14,
#   'contract_name': 'toulouse',
#   'name': '00014 - PERIGORD',
#   'address': '26 RUE DE PERIGORD',
#   'position': {'lat': 43.60742, 'lng': 1.444699},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 17,
#   'available_bike_stands': 12,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1759239564000},
#  {'number': 181,
#   'contract_name': 'toulouse',
#   'name': '00181 - PLANA - GARNIER',
#   'address': '27 AV LOUIS PLANA',
#   'position': {'lat': 43.609275, 'lng': 1.479898},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 17,
#   'available_bike_stands': 16,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239514000},
#  {'number': 50,
#   'contract_name': 'toulouse',
#   'name': '00050 - HAURIOU - GARONNETTE',
#   'address': '1 AV MAURICE HAURIOU',
#   'position': {'lat': 43.594359, 'lng': 1.44095},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 23,
#   'available_bike_stands': 11,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1759239432000},
#  {'number': 20,
#   'contract_name': 'toulouse',
#   'name': '00020 - CARNOT - TROIS JOURNEES',
#   'address': '69 BD LAZARE CARNOT',
#   'position': {'lat': 43.604677, 'lng': 1.449586},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 26,
#   'available_bike_stands': 19,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239618000},
#  {'number': 155,
#   'contract_name': 'toulouse',
#   'name': '00155 - RÉCOLLETS - FERETRA',
#   'address': '34 BD DES RECOLLETS',
#   'position': {'lat': 43.583787, 'lng': 1.443299},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 12,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1759239632000},
#  {'number': 256,
#   'contract_name': 'toulouse',
#   'name': "00256 - CITÉ DE L'HERS - ROTONDE",
#   'address': '4 RUE DE CARCASSONNE',
#   'position': {'lat': 43.596636, 'lng': 1.483995},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 16,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239241000},
#  {'number': 69,
#   'contract_name': 'toulouse',
#   'name': '00069 - FEUGA - PONT SAINT - MICHEL',
#   'address': '11 ALL PAUL FEUGA',
#   'position': {'lat': 43.592388, 'lng': 1.442463},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 18,
#   'available_bike_stands': 10,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1759239378000},
#  {'number': 157,
#   'contract_name': 'toulouse',
#   'name': '00157 - URSS - PEYROUSET',
#   'address': "16 AV DE L'U.R.S.S",
#   'position': {'lat': 43.58295, 'lng': 1.448578},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 19,
#   'available_bike_stands': 16,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1759239529000},
#  {'number': 189,
#   'contract_name': 'toulouse',
#   'name': '00189 - AV. DE MURET - BOUTINON',
#   'address': '46 AVENUE DE MURET',
#   'position': {'lat': 43.581793, 'lng': 1.425738},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 19,
#   'available_bike_stands': 14,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1759239612000}]

# %%
api_key = "ba66e04fc0c6389242d8598aeee0906fe4b3d805"
contract_name = 'toulouse'
station_number = 224
url = f'https://api.jcdecaux.com/vls/v3/stations/{station_number}?contract={contract_name}&apiKey={api_key}'
response = requests.get(url)
data = response.json()
data
# Out:
# {'number': 224,
#  'contractName': 'toulouse',
#  'name': '00224 - BELIN - SUPAERO',
#  'address': "10 AV EDOUARD BELIN FACE CHATEAU D'EAU CREPS RD-PT JEAN LAGASSE",
#  'position': {'latitude': 43.56644, 'longitude': 1.475301},
#  'banking': False,
#  'bonus': False,
#  'status': 'OPEN',
#  'lastUpdate': '2025-09-30T13:00:57Z',
#  'connected': True,
#  'overflow': False,
#  'shape': None,
#  'totalStands': {'availabilities': {'bikes': 20,
#    'stands': 0,
#    'mechanicalBikes': 15,
#    'electricalBikes': 5,
#    'electricalInternalBatteryBikes': 5,
#    'electricalRemovableBatteryBikes': 0},
#   'capacity': 20},
#  'mainStands': {'availabilities': {'bikes': 20,
#    'stands': 0,
#    'mechanicalBikes': 15,
#    'electricalBikes': 5,
#    'electricalInternalBatteryBikes': 5,
#    'electricalRemovableBatteryBikes': 0},
#   'capacity': 20},
#  'overflowStands': None}

# %%
pd.to_datetime
# Out:
#      number contract_name                                  name  \
# 0        55      toulouse  00055 - ST-SERNIN - GATIEN - ARNOULT
# 1       385      toulouse           00385 - VITARELLES - FRONDE
# 2       195      toulouse        00195 - RIEUX - CHANT DU MERLE
# 3        29      toulouse                        00029 - VALADE
# 4       400      toulouse    00400 - SAINT-MARTIN-DU-TOUCH GARE
# ..      ...           ...                                   ...
# 392     155      toulouse           00155 - RÉCOLLETS - FERETRA
# 393     256      toulouse      00256 - CITÉ DE L'HERS - ROTONDE
# 394      69      toulouse   00069 - FEUGA - PONT SAINT - MICHEL
# 395     157      toulouse              00157 - URSS - PEYROUSET
# 396     189      toulouse       00189 - AV. DE MURET - BOUTINON
#
#                                                address  \
# 0                                 2 RUE GATIEN ARNOULT
# 1                              21, chemin de la Fronde
# 2                          FACE 15 RUE PIERRE LAROUSSE
# 3                                        31 RUE VALADE
# 4    4, rue Marie Louise Dissard (sur la contre all...
# ..                                                 ...
# 392                                34 BD DES RECOLLETS
# 393                               4 RUE DE CARCASSONNE
# 394                                  11 ALL PAUL FEUGA
# 395                                 16 AV DE L'U.R.S.S
# 396                                 46 AVENUE DE MURET
#
#                                 position  banking  bonus  bike_stands  \
# 0    {'lat': 43.609022, 'lng': 1.441105}    False  False           15
# 1     {'lat': 43.587323, 'lng': 1.39462}    False  False           13
# 2    {'lat': 43.597355, 'lng': 1.459063}    False  False           18
# 3    {'lat': 43.605031, 'lng': 1.437386}    False  False           21
# 4    {'lat': 43.600614, 'lng': 1.372218}    False  False           13
# ..                                   ...      ...    ...          ...
# 392  {'lat': 43.583787, 'lng': 1.443299}    False  False           20
# 393  {'lat': 43.596636, 'lng': 1.483995}    False  False           18
# 394  {'lat': 43.592388, 'lng': 1.442463}    False  False           18
# 395   {'lat': 43.58295, 'lng': 1.448578}    False  False           19
# 396  {'lat': 43.581793, 'lng': 1.425738}    False  False           19
#
#      available_bike_stands  available_bikes status    last_update
# 0                       13                1   OPEN  1758722890000
# 1                       12                1   OPEN  1758722756000
# 2                        7               10   OPEN  1758723267000
# 3                       20                0   OPEN  1758723191000
# 4                        0               13   OPEN  1758723204000
# ..                     ...              ...    ...            ...
# 392                     11                9   OPEN  1758723115000
# 393                     16                1   OPEN  1758723187000
# 394                     12                4   OPEN  1758723010000
# 395                     16                3   OPEN  1758723255000
# 396                     13                3   OPEN  1758723244000
#
# [397 rows x 12 columns]

# %%
url = f"https://data.toulouse-metropole.fr/api/explore/v2.1/catalog/datasets/api-velo-toulouse-temps-reel/records?limit=20"
response = requests.get(url)
data = response.json()
df = pd.DataFrame(data)

# %%
url = f"https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel"
response = requests.get(url)
data = response.json()

# %%
data
# Out:
# {'links': [{'rel': 'self',
#    'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel'},
#   {'rel': 'datasets',
#    'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'},
#   {'rel': 'records',
#    'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/records'},
#   {'rel': 'exports',
#    'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/exports'},
#   {'rel': 'facets',
#    'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/facets'},
#   {'rel': 'reuses',
#    'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/reuses'}],
#  'dataset': {'visibility': 'domain',
#   'dataset_id': 'api-velo-toulouse-temps-reel',
#   'dataset_uid': 'da_n1l1x4',
#   'has_records': True,
#   'features': ['geo', 'analyze', 'timeserie'],
#   'attachments': [],
#   'alternative_exports': [],
#   'data_visible': True,
#   'fields': [{'name': 'number',
#     'annotations': {'id': True},
#     'label': 'number',
#     'type': 'int',
#     'description': None},
#    {'name': 'name',
#     'label': 'name',
#     'type': 'text',
#     'annotations': {},
#     'description': None},
#    {'name': 'address',
#     'label': 'address',
#     'type': 'text',
#     'annotations': {},
#     'description': None},
#    {'name': 'position',
#     'label': 'position',
#     'type': 'geo_point_2d',
#     'annotations': {},
#     'description': None},
#    {'name': 'banking',
#     'annotations': {'facet': True},
#     'label': 'banking',
#     'type': 'text',
#     'description': None},
#    {'name': 'bonus',
#     'annotations': {'facet': True},
#     'label': 'bonus',
#     'type': 'text',
#     'description': None},
#    {'name': 'status',
#     'annotations': {'facet': True},
#     'label': 'status',
#     'type': 'text',
#     'description': None},
#    {'name': 'contract_name',
#     'annotations': {'facet': True, 'id': True},
#     'label': 'Contract Name',
#     'type': 'text',
#     'description': None},
#    {'name': 'bike_stands',
#     'label': 'Bike Stands',
#     'type': 'int',
#     'annotations': {},
#     'description': None},
#    {'name': 'available_bike_stands',
#     'label': 'Available Bike Stands',
#     'type': 'int',
#     'annotations': {},
#     'description': None},
#    {'name': 'available_bikes',
#     'label': 'Available Bikes',
#     'type': 'int',
#     'annotations': {},
#     'description': None},
#    {'name': 'last_update',
#     'label': 'Last Update',
#     'type': 'datetime',
#     'annotations': {},
#     'description': None}],
#   'metas': {'dcat': {'created': '2022-08-12',
#     'issued': '2022-08-12',
#     'creator': 'JC DECAUX',
#     'contributor': 'JCDecaux',
#     'contact_name': None,
#     'contact_email': None,
#     'accrualperiodicity': None,
#     'spatial': None,
#     'temporal': None,
#     'granularity': None,
#     'dataquality': None,
#     'publisher_type': None,
#     'conforms_to': None,
#     'temporal_coverage_start': None,
#     'temporal_coverage_end': None,
#     'accessRights': None,
#     'relation': None},
#    'inspire': {'theme': None,
#     'type': None,
#     'file_identifier': None,
#     'hierarchy_level': None,
#     'hierarchy_level_name': None,
#     'spatial_resolution': None,
#     'topologic_consistency': None,
#     'contact_individual_name': None,
#     'contact_position': None,
#     'contact_address': None,
#     'contact_email': None,
#     'identification_purpose': None,
#     'extend_description': None,
#     'extend_bounding_box_westbound_longitude': None,
#     'extend_bounding_box_eastbound_longitude': None,
#     'extend_bounding_box_southbound_latitude': None,
#     'extend_bounding_box_northbound_latitude': None},
#    'default': {'title': 'Vélos en libre-service (VélÔToulouse API JC Decaux)',
#     'description': '<p>Cette fiche renvoie à l\'API "JCDecaux developer" qui met à disposition les données des stations vélos "VelôToulouse" depuis le 03 Mai 2013 .</p><p>Pour plus d\'information, rendez-vous à l\'URL suivante : <a href="https://developer.jcdecaux.com/#/home">https://developer.jcdecaux.com/#/home</a></p><p>Le lien renvoie sur le tutoriel de l\'API, pour obtenir la clé d\'API de Toulouse, il suffit de vous créer un compte.  </p>',
#     'theme': ['Transport'],
#     'keyword': ['vélo', 'station', 'JCDecaux', 'disponibilité', 'mode doux'],
#     'license': 'Licence Ouverte v2.0 (Etalab)',
#     'license_url': 'https://www.etalab.gouv.fr/wp-content/uploads/2017/04/ETALAB-Licence-Ouverte-v2.0.pdf',
#     'language': 'en',
#     'metadata_languages': ['en'],
#     'timezone': ['Europe/Paris'],
#     'modified': '2022-09-20T10:21:55+00:00',
#     'modified_updates_on_metadata_change': True,
#     'modified_updates_on_data_change': True,
#     'data_processed': '2025-09-24T01:00:03+00:00',
#     'metadata_processed': '2025-09-24T01:12:52.290000+00:00',
#     'geographic_reference': ['fr_60_32', 'fr_60_31'],
#     'geographic_reference_auto': True,
#     'territory': ['Gers', 'Haute-Garonne'],
#     'geometry_types': ['Point'],
#     'bbox': {'type': 'Feature',
#      'geometry': {'coordinates': [[[1.5060709230601788, 43.66750697605312],
#         [1.0001754574477673, 43.66750697605312],
#         [1.0001754574477673, 43.548386972397566],
#         [1.5060709230601788, 43.548386972397566],
#         [1.5060709230601788, 43.66750697605312]]],
#       'type': 'Polygon'},
#      'properties': {}},
#     'publisher': 'JCDecaux',
#     'references': 'https://developer.jcdecaux.com/#/opendata/vls?page=dynamic',
#     'records_count': 416,
#     'attributions': ['JCDecaux'],
#     'source_domain': None,
#     'source_domain_title': None,
#     'source_domain_address': None,
#     'source_dataset': None,
#     'shared_catalog': None,
#     'federated': True,
#     'parent_domain': None,
#     'update_frequency': None},
#    'custom': {'villes-concernees': None, 'cycle': None, 'periodicity': None}}}}

# %%
dict_url = {
   # 'catalog': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel',
   # 'datasets': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets',
   'records': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/records',
   'exports': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/exports',
   'facets': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/facets',
   'reuses': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/reuses'
}

# %%
dict_df = dict()
for key, url in dict_url.items():
    response = requests.get(url)
    data = response.json()
    print(data)
    dict_df[key] = pd.DataFrame(data)
# Out:
# {'total_count': 419, 'links': [{'rel': 'self', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/records?limit=10&offset=0&include_app_metas=False&include_links=False'}, {'rel': 'first', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/records?limit=10&offset=0&include_app_metas=False&include_links=False'}, {'rel': 'last', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/records?limit=10&offset=410&include_app_metas=False&include_links=False'}, {'rel': 'next', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/records?limit=10&offset=10&include_app_metas=False&include_links=False'}], 'records': [{'links': [{'rel': 'self', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/records/569dca1a557c905af8976a3dca4ee11a44fe7ad2'}, {'rel': 'datasets', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'}, {'rel': 'dataset', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel'}], 'record': {'id': '569dca1a557c905af8976a3dca4ee11a44fe7ad2', 'timestamp': None, 'size': 194, 'fields': {'number': 408, 'name': '00408 - BRUNAUD - CEAT', 'address': 'Face 76, avenue Yves Brunaud - Toulouse', 'position': {'lon': 1.466289, 'lat': 43.617615}, 'banking': 'False', 'bonus': 'False', 'status': 'OPEN', 'contract_name': 'toulouse', 'bike_stands': 16, 'available_bike_stands': 16, 'available_bikes': 0, 'last_update': '2025-09-24T13:53:31+00:00'}}}, {'links': [{'rel': 'self', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/records/fb2f1da93db1a2b05fe45777fb6d57133bb1a6bf'}, {'rel': 'datasets', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'}, {'rel': 'dataset', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel'}], 'record': {'id': 'fb2f1da93db1a2b05fe45777fb6d57133bb1a6bf', 'timestamp': None, 'size': 216, 'fields': {'number': 253, 'name': '00253 - ÉTATS-UNIS - CHARLAS', 'address': 'FACE 74 AV DES ETATS-UNIS (GARAGE RENAULT TOULOUSE)', 'position': {'lon': 1.43234, 'lat': 43.630519}, 'banking': 'False', 'bonus': 'False', 'status': 'OPEN', 'contract_name': 'toulouse', 'bike_stands': 20, 'available_bike_stands': 17, 'available_bikes': 2, 'last_update': '2025-09-24T13:58:22+00:00'}}}, {'links': [{'rel': 'self', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/records/91d2e26e07526409be47b4fcdb3f04742ace556e'}, {'rel': 'datasets', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'}, {'rel': 'dataset', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel'}], 'record': {'id': '91d2e26e07526409be47b4fcdb3f04742ace556e', 'timestamp': None, 'size': 215, 'fields': {'number': 412, 'name': '00412 - PARC DE LA POUDRERIE', 'address': 'Face 8 et 9 chemin de la loge Ile du Ramier - Toulouse', 'position': {'lon': 1.43429, 'lat': 43.576697}, 'banking': 'False', 'bonus': 'False', 'status': 'CLOSED', 'contract_name': 'toulouse', 'bike_stands': 16, 'available_bike_stands': 0, 'available_bikes': 0, 'last_update': '2025-09-24T13:56:55+00:00'}}}, {'links': [{'rel': 'self', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/records/58dc2dd2f30ba21ac0a232b4a25def9089c3b685'}, {'rel': 'datasets', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'}, {'rel': 'dataset', 'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel'}], 'record': {'id': '58dc2dd2f30ba21ac0a232b4a25def9089c3b685', 'timestamp': None, 'size':  ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 6
#       4 data = response.json()
#       5 print(data)
# ----> 6 dict_df[key] = pd.DataFrame(data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
key='reuses'
url = dict_url[key]
response = requests.get(url)
data = response.json()
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 5
#       3 response = requests.get(url)
#       4 data = response.json()
# ----> 5 df = pd.DataFrame(data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
data
# Out:
# {'links': [{'rel': 'self',
#    'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/reuses?limit=10&offset=0'},
#   {'rel': 'first',
#    'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/reuses?limit=10&offset=0'},
#   {'rel': 'last',
#    'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/reuses?limit=10&offset=0'}],
#  'reuses': [{'id': 432,
#    'user': {'username': None, 'first_name': 'Olivier', 'last_name': 'LOBET'},
#    'title': 'Véloccitan, tout savoir sur le vélo à Toulouse !',
#    'description': 'Application permettant de visualiser les stations de vélotoulouse de la ville,  consulter la disponibilité des vélos en temps réel (nombre de vélos, nombre de places de stationnement libres), enregistrer ses stations préférées en favoris, créer des itinéraires, visualiser le réseau cyclable, les chantiers en temps réel... Application disponible sur Google Play et sur https://veloccitan.fr',
#    'url': 'https://veloccitan.fr/',
#    'thumbnail': ['https://data.toulouse-metropole.frhttps://s3-eu-west-1.amazonaws.com/aws-ec2-eu-1-opendatasoft-staticfileset/toulouse-metropole/api-velo-toulouse-temps-reel/api-velo-toulouse-temps-reel_432_16783527770366108.png'],
#    'created_at': '2021-05-18T17:05:27+00:00'},
#   {'id': 78,
#    'user': {'username': 'astm', 'first_name': 'Audrey', 'last_name': 'SIMON'},
#    'title': 'Géovélo',
#    'description': "L'application s'adapte à votre type de vélo, à votre vitesse moyenne de déplacement, au type de parcours souhaité (du plus rapide au plus sécurisé). Géovélo choisit en priorité les pistes, bandes cyclables et rues peu passantes pour vous assurer confort, sécurité et tranquillité.\r\nGéovélo utilise les données fournies par VélôToulouse pour afficher les positions et disponilibilités des vélos et places de stationnement en temps réel.",
#    'url': 'https://itunes.apple.com/fr/app/geovelo-toulouse/id990761979?mt=8',
#    'thumbnail': ['https://data.toulouse-metropole.frhttps://s3-eu-west-1.amazonaws.com/aws-ec2-eu-1-opendatasoft-staticfileset/toulouse-metropole/api-velo-toulouse-temps-reel/api-velo-toulouse-temps-reel_37_144370960462.png'],
#    'created_at': '2015-10-01T14:26:44+00:00'}]}

# %%
data
# Out:
# {'total_count': 790,
#  'links': [{'rel': 'self',
#    'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets?limit=10&offset=0&include_app_metas=False&include_links=False'},
#   {'rel': 'first',
#    'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets?limit=10&offset=0&include_app_metas=False&include_links=False'},
#   {'rel': 'last',
#    'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets?limit=10&offset=780&include_app_metas=False&include_links=False'},
#   {'rel': 'next',
#    'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets?limit=10&offset=10&include_app_metas=False&include_links=False'}],
#  'datasets': [{'links': [{'rel': 'self',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2017-blagnac'},
#     {'rel': 'datasets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'records',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2017-blagnac/records'},
#     {'rel': 'exports',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2017-blagnac/exports'},
#     {'rel': 'facets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2017-blagnac/facets'},
#     {'rel': 'reuses',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2017-blagnac/reuses'}],
#    'dataset': {'visibility': 'domain',
#     'dataset_id': 'budget-primitif-2017-blagnac',
#     'dataset_uid': 'da_6e0yom',
#     'has_records': True,
#     'features': ['analyze'],
#     'attachments': [],
#     'alternative_exports': [],
#     'data_visible': True,
#     'fields': [{'name': 'exercice',
#       'description': None,
#       'annotations': {},
#       'label': 'Exercice',
#       'type': 'double'},
#      {'name': 'entite_financiere',
#       'description': None,
#       'annotations': {},
#       'label': 'Entité Financière',
#       'type': 'text'},
#      {'name': 'type_de_mouvements',
#       'description': None,
#       'annotations': {},
#       'label': 'Type de mouvements',
#       'type': 'text'},
#      {'name': 'section',
#       'description': None,
#       'annotations': {},
#       'label': 'Section',
#       'type': 'text'},
#      {'name': 'nomenclature',
#       'description': None,
#       'annotations': {},
#       'label': 'Nomenclature',
#       'type': 'text'},
#      {'name': 'chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Chapitre',
#       'type': 'text'},
#      {'name': 'libelle_chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Chapitre',
#       'type': 'text'},
#      {'name': 'article',
#       'description': None,
#       'annotations': {},
#       'label': 'Article',
#       'type': 'text'},
#      {'name': 'libelle_article',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Article',
#       'type': 'text'},
#      {'name': 'code_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Code fonction',
#       'type': 'text'},
#      {'name': 'libelle_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé fonction',
#       'type': 'text'},
#      {'name': 'mt_vote_bp_depense',
#       'description': None,
#       'annotations': {},
#       'label': 'MT Voté BP Dépense',
#       'type': 'double'},
#      {'name': 'mt_vote_bp_recette',
#       'description': None,
#       'annotations': {},
#       'label': 'MT Voté BP Recette',
#       'type': 'double'}],
#     'metas': {'dcat': {'created': '2019-04-11',
#       'issued': None,
#       'creator': 'Direction des Finances Blagnac',
#       'contributor': 'DSI Blagnac',
#       'contact_name': None,
#       'contact_email': None,
#       'accrualperiodicity': 'Annuelle',
#       'spatial': 'Ville de Blagnac',
#       'temporal': 'Année',
#       'granularity': 'Compte M14',
#       'dataquality': None,
#       'publisher_type': None,
#       'conforms_to': None,
#       'temporal_coverage_start': None,
#       'temporal_coverage_end': None,
#       'accessRights': None,
#       'relation': None},
#      'inspire': {'theme': None,
#       'type': None,
#       'file_identifier': None,
#       'hierarchy_level': None,
#       'hierarchy_level_name': None,
#       'spatial_resolution': None,
#       'topologic_consistency': None,
#       'contact_individual_name': None,
#       'contact_position': None,
#       'contact_address': None,
#       'contact_email': None,
#       'identification_purpose': None,
#       'extend_description': None,
#       'extend_bounding_box_westbound_longitude': None,
#       'extend_bounding_box_eastbound_longitude': None,
#       'extend_bounding_box_southbound_latitude': None,
#       'extend_bounding_box_northbound_latitude': None},
#      'default': {'title': 'Budget primitif 2017 - Blagnac',
#       'description': None,
#       'theme': ['Finance'],
#       'keyword': ['budget', 'budget primitif', 'finances', 'primitif'],
#       'license': 'Open Database License (ODbL)',
#       'license_url': 'http://opendatacommons.org/licenses/odbl/',
#       'language': 'fr',
#       'metadata_languages': ['fr'],
#       'timezone': None,
#       'modified': '2019-04-11T11:01:56+00:00',
#       'modified_updates_on_metadata_change': False,
#       'modified_updates_on_data_change': False,
#       'data_processed': '2019-04-11T13:06:35+00:00',
#       'metadata_processed': '2025-04-30T08:43:48.150000+00:00',
#       'geographic_reference': ['fr_70_243100518'],
#       'geographic_reference_auto': True,
#       'territory': ['Toulouse Métropole'],
#       'geometry_types': None,
#       'bbox': None,
#       'publisher': 'Ville de Blagnac',
#       'references': None,
#       'records_count': 1135,
#       'attributions': None,
#       'source_domain': None,
#       'source_domain_title': None,
#       'source_domain_address': None,
#       'source_dataset': None,
#       'shared_catalog': None,
#       'federated': False,
#       'parent_domain': None,
#       'update_frequency': None},
#      'custom': {'villes-concernees': ['Blagnac'],
#       'cycle': None,
#       'periodicity': None}}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2023-regie-restauration-blagnac'},
#     {'rel': 'datasets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'records',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2023-regie-restauration-blagnac/records'},
#     {'rel': 'exports',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2023-regie-restauration-blagnac/exports'},
#     {'rel': 'facets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2023-regie-restauration-blagnac/facets'},
#     {'rel': 'reuses',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2023-regie-restauration-blagnac/reuses'}],
#    'dataset': {'visibility': 'domain',
#     'dataset_id': 'budget-primitif-2023-regie-restauration-blagnac',
#     'dataset_uid': 'da_qmzaeq',
#     'has_records': True,
#     'features': ['analyze'],
#     'attachments': [],
#     'alternative_exports': [],
#     'data_visible': True,
#     'fields': [{'name': 'exercice',
#       'description': None,
#       'annotations': {},
#       'label': 'Exercice',
#       'type': 'text'},
#      {'name': 'entite_financiere',
#       'description': None,
#       'annotations': {},
#       'label': 'Entité Financière',
#       'type': 'text'},
#      {'name': 'type_de_mouvements',
#       'description': None,
#       'annotations': {},
#       'label': 'Type de mouvements',
#       'type': 'text'},
#      {'name': 'section',
#       'description': None,
#       'annotations': {},
#       'label': 'Section',
#       'type': 'text'},
#      {'name': 'nomenclature',
#       'description': None,
#       'annotations': {},
#       'label': 'Nomenclature',
#       'type': 'text'},
#      {'name': 'chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Chapitre',
#       'type': 'int'},
#      {'name': 'libelle_chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Chapitre',
#       'type': 'text'},
#      {'name': 'article',
#       'description': None,
#       'annotations': {},
#       'label': 'Article',
#       'type': 'int'},
#      {'name': 'libelle_article',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Article',
#       'type': 'text'},
#      {'name': 'code_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Code fonction',
#       'type': 'int'},
#      {'name': 'libelle_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé fonction',
#       'type': 'text'},
#      {'name': 'mt_vote_bp_depense',
#       'description': None,
#       'annotations': {},
#       'label': 'MT Voté BP Dépense',
#       'type': 'text'},
#      {'name': 'mt_vote_bp_recette',
#       'description': None,
#       'annotations': {},
#       'label': 'MT Voté BP Recette',
#       'type': 'text'}],
#     'metas': {'dcat': {'created': None,
#       'issued': None,
#       'creator': None,
#       'contributor': None,
#       'contact_name': None,
#       'contact_email': None,
#       'accrualperiodicity': None,
#       'spatial': None,
#       'temporal': None,
#       'granularity': None,
#       'dataquality': None,
#       'publisher_type': None,
#       'conforms_to': None,
#       'temporal_coverage_start': None,
#       'temporal_coverage_end': None,
#       'accessRights': None,
#       'relation': None},
#      'inspire': {'theme': None,
#       'type': None,
#       'file_identifier': None,
#       'hierarchy_level': None,
#       'hierarchy_level_name': None,
#       'spatial_resolution': None,
#       'topologic_consistency': None,
#       'contact_individual_name': None,
#       'contact_position': None,
#       'contact_address': None,
#       'contact_email': None,
#       'identification_purpose': None,
#       'extend_description': None,
#       'extend_bounding_box_westbound_longitude': None,
#       'extend_bounding_box_eastbound_longitude': None,
#       'extend_bounding_box_southbound_latitude': None,
#       'extend_bounding_box_northbound_latitude': None},
#      'default': {'title': 'Budget Primitif 2023 - Régie Restauration Blagnac',
#       'description': None,
#       'theme': ['Finance'],
#       'keyword': ['Blagnac',
#        'RMR',
#        'cantine',
#        'restauration',
#        '2023',
#        'budget',
#        'primitif'],
#       'license': 'Open Database License (ODbL)',
#       'license_url': 'http://opendatacommons.org/licenses/odbl/',
#       'language': 'fr',
#       'metadata_languages': ['fr'],
#       'timezone': None,
#       'modified': '2025-07-29T08:09:48+00:00',
#       'modified_updates_on_metadata_change': False,
#       'modified_updates_on_data_change': False,
#       'data_processed': '2025-07-29T08:10:59+00:00',
#       'metadata_processed': '2025-07-31T13:54:24.915000+00:00',
#       'geographic_reference': None,
#       'geographic_reference_auto': False,
#       'territory': None,
#       'geometry_types': None,
#       'bbox': None,
#       'publisher': 'Ville de Blagnac',
#       'references': None,
#       'records_count': 59,
#       'attributions': None,
#       'source_domain': None,
#       'source_domain_title': None,
#       'source_domain_address': None,
#       'source_dataset': None,
#       'shared_catalog': None,
#       'federated': False,
#       'parent_domain': None,
#       'update_frequency': None},
#      'custom': {'villes-concernees': ['Blagnac'],
#       'cycle': None,
#       'periodicity': None}}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/11-station-meteo-toulouse-soupetard-archive-2021'},
#     {'rel': 'datasets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'records',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/11-station-meteo-toulouse-soupetard-archive-2021/records'},
#     {'rel': 'exports',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/11-station-meteo-toulouse-soupetard-archive-2021/exports'},
#     {'rel': 'facets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/11-station-meteo-toulouse-soupetard-archive-2021/facets'},
#     {'rel': 'reuses',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/11-station-meteo-toulouse-soupetard-archive-2021/reuses'}],
#    'dataset': {'visibility': 'domain',
#     'dataset_id': '11-station-meteo-toulouse-soupetard-archive-2021',
#     'dataset_uid': 'da_zno8ob',
#     'has_records': True,
#     'features': ['analyze', 'timeserie'],
#     'attachments': [],
#     'alternative_exports': [],
#     'data_visible': True,
#     'fields': [{'name': 'data',
#       'description': 'message brut en provenance de la station météo',
#       'annotations': {},
#       'label': 'data',
#       'type': 'text'},
#      {'name': 'id',
#       'description': 'Identifiant de la station la station n°1 est celle de la météopole',
#       'annotations': {'facetsort': '-count'},
#       'label': 'id',
#       'type': 'int'},
#      {'name': 'dd_mm_yy_hh_mm_utc',
#       'description': 'Date et heure UTC à laquelle le message contenant les données est envoyé depuis la station',
#       'annotations': {'facetsort': '-count', 'timeserie_precision': 'hour'},
#       'label': 'dd_mm_yy_hh_mm_utc',
#       'type': 'datetime'},
#      {'name': 'numero_de_message',
#       'description': "Représentatif de l'heure :\nla journée est découpée en quarts d'heures. Le message n°1 est celui envoyé a 00h01 UTC\nil y a 96 messages par jour par capteur",
#       'annotations': {'facetsort': '-count'},
#       'label': 'numero_de_message',
#       'type': 'int'},
#      {'name': 'temperature',
#       'description': None,
#       'annotations': {},
#       'label': 'temperature',
#       'type': 'double'},
#      {'name': 'direction_du_vecteur_vent_moyen',
#       'description': 'Angle entre la direction de laquelle vient vent  par rapport à une référence cardinale qui est ici le nord',
#       'annotations': {'facetsort': '-count', 'unit': '°'},
#       'label': 'direction_du_vecteur_vent_moyen',
#       'type': 'int'},
#      {'name': 'direction_du_vecteur_de_rafale_de_vent_max',
#       'description': 'Cette valeur représente la direction de la rafale maximum sur les 15 minutes précédentes en degrés.',
#       'annotations': {'unit': '°'},
#       'label': 'direction_du_vecteur_de_rafale_de_vent_max',
#       'type': 'double'},
#      {'name': 'force_du_vecteur_de_vent_max',
#       'description': "Comme pour la force du vecteur de vent moyen, la donnée doit subir la même opération. Cette valeur représente la rafale maximum sur les 15 minutes. cette valeur n'est pas moyennée.",
#       'annotations': {'facetsort': '-count'},
#       'label': 'force_du_vecteur_de_vent_max',
#       'type': 'int'},
#      {'name': 'force_moyenne_du_vecteur_de_vent',
#       'description': "Ce champ représente la vitesse du vent issue de la moyenne du vecteur vent sur 15 minutes. \nAttention, Les valeurs contenus dans ce champ ne suivent pas une échelle linéaire : en dessous de 80 km/h l'échlle est linéaire, 1km/h réel = 1km/h du champ de données et au dessus de 80km/h, 2km/h réels = 1km/h du champ de données\n(précisions dans un document annexe)",
#       'annotations': {'facetsort': '-count'},
#       'label': 'force_moyenne_du_vecteur_de_vent',
#       'type': 'int'},
#      {'name': 'pression',
#       'description': 'valeur de pression. La valeur contenues dans ce champ doivent être additionnées à 900. ',
#       'annotations': {'facetsort': '-count', 'unit': 'Pa'},
#       'label': 'pression',
#       'type': 'int'},
#      {'name': 'humidite',
#       'description': "Valeur d'humidité en pourcentage",
#       'annotations': {'facetsort': '-count', 'unit': '%'},
#       'label': 'humidite',
#       'type': 'int'},
#      {'name': 'pluie',
#       'description': 'quantité de précipitation en mm.',
#       'annotations': {'facetsort': '-count', 'unit': 'mm'},
#       'label': 'pluie',
#       'type': 'double'},
#      {'name': 'pluie_intensite_max',
#       'description': 'Intensité maximale de pluie sur une minute.',
#       'annotations': {'facetsort': '-count', 'unit': 'mm'},
#       'label': 'pluie_intensite_max',
#       'type': 'double'},
#      {'name': 'type_de_station',
#       'description': 'Il existe deux types de stations : Integrated Sensor Suite (ISS) regroupant uncapteur de : Température, Humidité, Anémomètre, Pluviomètre, Capteur de Pression',
#       'annotations': {},
#       'label': 'type_de_station',
#       'type': 'text'},
#      {'name': 'sous_station',
#       'description': 'Indique le type de station. \n0 pour une station normale\n1 pour une sous-station',
#       'annotations': {'facetsort': '-count'},
#       'label': 'type_station',
#       'type': 'int'}],
#     'metas': {'dcat': {'created': '2019-05-14',
#       'issued': '2019-05-21',
#       'creator': 'Toulouse Métropole',
#       'contributor': "Direction de l'Environnement",
#       'contact_name': None,
#       'contact_email': None,
#       'accrualperiodicity': "Tous les quarts d'heure",
#       'spatial': None,
#       'temporal': None,
#       'granularity': None,
#       'dataquality': None,
#       'publisher_type': None,
#       'conforms_to': None,
#       'temporal_coverage_start': None,
#       'temporal_coverage_end': None,
#       'accessRights': None,
#       'relation': None},
#      'inspire': {'theme': None,
#       'type': None,
#       'file_identifier': None,
#       'hierarchy_level': None,
#       'hierarchy_level_name': None,
#       'spatial_resolution': None,
#       'topologic_consistency': None,
#       'contact_individual_name': None,
#       'contact_position': None,
#       'contact_address': None,
#       'contact_email': None,
#       'identification_purpose': None,
#       'extend_description': None,
#       'extend_bounding_box_westbound_longitude': None,
#       'extend_bounding_box_eastbound_longitude': None,
#       'extend_bounding_box_southbound_latitude': None,
#       'extend_bounding_box_northbound_latitude': None},
#      'default': {'title': '11 Station météo Toulouse Soupetard - archive 2021',
#       'description': '<p style="font-family: sans-serif;"><span style="font-size: 0.875rem;">Ce jeu\xa0</span><span style="font-size: 0.875rem;">est une archive</span><span style="font-size: 0.875rem;">\xa0</span><span style="font-family: inherit; font-size: 0.875rem;">des données issues du capteur</span><span style="font-size: 0.875rem;"><font color="#808080" face="-apple-system, BlinkMacSystemFont, Segoe UI, Roboto, Helvetica, Arial, sans-serif">\xa0</font></span><span style="font-size: 0.875rem;">n° 11 situé sur le site de l\'école maternelle des Acacias (Quartier Soupetard à Toulouse)</span><span style="font-size: 0.875rem;">\xa0</span><span style="font-family: inherit; font-size: 0.875rem;">qui fait partie d\'un réseau de stations météo situées sur la métropole Toulousaine en vue d\'étudier le phénomène d\'Ilot de Chaleur Urbain (ICU)</span></p><p style="font-family: sans-serif;"><span style="font-family: inherit; font-size: 0.875rem;">Les données relatives à la pluie sont effectives à partir de 2022.</span></p>',
#       'theme': ['Environnement'],
#       'keyword': ['météo',
#        'ilot de chaleur',
#        'température',
#        'station météo',
#        'precipitations'],
#       'license': 'Licence Ouverte v2.0 (Etalab)',
#       'license_url': 'https://www.etalab.gouv.fr/wp-content/uploads/2017/04/ETALAB-Licence-Ouverte-v2.0.pdf',
#       'language': 'fr',
#       'metadata_languages': ['fr'],
#       'timezone': None,
#       'modified': '2022-12-20T14:33:40+00:00',
#       'modified_updates_on_metadata_change': False,
#       'modified_updates_on_data_change': True,
#       'data_processed': '2022-12-20T14:33:40+00:00',
#       'metadata_processed': '2022-12-20T14:43:15.059000+00:00',
#       'geographic_reference': ['fr_70_243100518'],
#       'geographic_reference_auto': True,
#       'territory': ['Toulouse Métropole'],
#       'geometry_types': None,
#       'bbox': None,
#       'publisher': 'Toulouse Métropole',
#       'references': None,
#       'records_count': 29913,
#       'attributions': None,
#       'source_domain': None,
#       'source_domain_title': None,
#       'source_domain_address': None,
#       'source_dataset': None,
#       'shared_catalog': None,
#       'federated': False,
#       'parent_domain': None,
#       'update_frequency': None},
#      'custom': {'villes-concernees': None,
#       'cycle': None,
#       'periodicity': None}}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2017-aeroscopia-blagnac'},
#     {'rel': 'datasets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'records',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2017-aeroscopia-blagnac/records'},
#     {'rel': 'exports',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2017-aeroscopia-blagnac/exports'},
#     {'rel': 'facets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2017-aeroscopia-blagnac/facets'},
#     {'rel': 'reuses',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2017-aeroscopia-blagnac/reuses'}],
#    'dataset': {'visibility': 'domain',
#     'dataset_id': 'budget-primitif-2017-aeroscopia-blagnac',
#     'dataset_uid': 'da_gs72qb',
#     'has_records': True,
#     'features': ['analyze'],
#     'attachments': [],
#     'alternative_exports': [],
#     'data_visible': True,
#     'fields': [{'name': 'exercice',
#       'description': None,
#       'annotations': {},
#       'label': 'Exercice',
#       'type': 'double'},
#      {'name': 'entite_financiere',
#       'description': None,
#       'annotations': {},
#       'label': 'Entité Financière',
#       'type': 'text'},
#      {'name': 'type_de_mouvements',
#       'description': None,
#       'annotations': {},
#       'label': 'Type de mouvements',
#       'type': 'text'},
#      {'name': 'section',
#       'description': None,
#       'annotations': {},
#       'label': 'Section',
#       'type': 'text'},
#      {'name': 'nomenclature',
#       'description': None,
#       'annotations': {},
#       'label': 'Nomenclature',
#       'type': 'text'},
#      {'name': 'chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Chapitre',
#       'type': 'text'},
#      {'name': 'libelle_chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Chapitre',
#       'type': 'text'},
#      {'name': 'article',
#       'description': None,
#       'annotations': {},
#       'label': 'Article',
#       'type': 'text'},
#      {'name': 'libelle_article',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Article',
#       'type': 'text'},
#      {'name': 'code_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Code fonction',
#       'type': 'text'},
#      {'name': 'libelle_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé fonction',
#       'type': 'text'},
#      {'name': 'mt_vote_bp_depense',
#       'description': None,
#       'annotations': {},
#       'label': 'MT Voté BP Dépense',
#       'type': 'double'},
#      {'name': 'mt_vote_bp_recette',
#       'description': None,
#       'annotations': {},
#       'label': 'MT Voté BP Recette',
#       'type': 'double'}],
#     'metas': {'dcat': {'created': '2019-04-12',
#       'issued': '2019-04-12',
#       'creator': 'Direction des Finances Blagnac',
#       'contributor': 'DSI Blagnac',
#       'contact_name': None,
#       'contact_email': None,
#       'accrualperiodicity': 'annuelle',
#       'spatial': 'Ville de Blagnac',
#       'temporal': 'Année',
#       'granularity': 'Compte M14',
#       'dataquality': None,
#       'publisher_type': None,
#       'conforms_to': None,
#       'temporal_coverage_start': None,
#       'temporal_coverage_end': None,
#       'accessRights': None,
#       'relation': None},
#      'inspire': {'theme': None,
#       'type': None,
#       'file_identifier': None,
#       'hierarchy_level': None,
#       'hierarchy_level_name': None,
#       'spatial_resolution': None,
#       'topologic_consistency': None,
#       'contact_individual_name': None,
#       'contact_position': None,
#       'contact_address': None,
#       'contact_email': None,
#       'identification_purpose': None,
#       'extend_description': None,
#       'extend_bounding_box_westbound_longitude': None,
#       'extend_bounding_box_eastbound_longitude': None,
#       'extend_bounding_box_southbound_latitude': None,
#       'extend_bounding_box_northbound_latitude': None},
#      'default': {'title': 'Budget primitif 2017 - Aéroscopia Blagnac',
#       'description': None,
#       'theme': ['Finance'],
#       'keyword': ['aéroscopia',
#        'aéronautique',
#        'budget',
#        'budget primitif',
#        'finances',
#        'primitif'],
#       'license': 'Open Database License (ODbL)',
#       'license_url': 'http://opendatacommons.org/licenses/odbl/',
#       'language': 'fr',
#       'metadata_languages': ['fr'],
#       'timezone': None,
#       'modified': '2019-04-12T06:58:14+00:00',
#       'modified_updates_on_metadata_change': False,
#       'modified_updates_on_data_change': False,
#       'data_processed': '2019-04-12T07:02:48+00:00',
#       'metadata_processed': '2025-04-30T08:39:14.652000+00:00',
#       'geographic_reference': ['fr_70_243100518'],
#       'geographic_reference_auto': True,
#       'territory': ['Toulouse Métropole'],
#       'geometry_types': None,
#       'bbox': None,
#       'publisher': 'Ville de Blagnac',
#       'references': None,
#       'records_count': 17,
#       'attributions': None,
#       'source_domain': None,
#       'source_domain_title': None,
#       'source_domain_address': None,
#       'source_dataset': None,
#       'shared_catalog': None,
#       'federated': False,
#       'parent_domain': None,
#       'update_frequency': None},
#      'custom': {'villes-concernees': ['Blagnac'],
#       'cycle': None,
#       'periodicity': None}}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/ca-2015-blagnac'},
#     {'rel': 'datasets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'records',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/ca-2015-blagnac/records'},
#     {'rel': 'exports',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/ca-2015-blagnac/exports'},
#     {'rel': 'facets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/ca-2015-blagnac/facets'},
#     {'rel': 'reuses',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/ca-2015-blagnac/reuses'}],
#    'dataset': {'visibility': 'domain',
#     'dataset_id': 'ca-2015-blagnac',
#     'dataset_uid': 'da_pqse3v',
#     'has_records': True,
#     'features': ['analyze'],
#     'attachments': [],
#     'alternative_exports': [],
#     'data_visible': True,
#     'fields': [{'name': 'exercice',
#       'description': None,
#       'annotations': {},
#       'label': 'Exercice ',
#       'type': 'double'},
#      {'name': 'entite_financiere',
#       'description': None,
#       'annotations': {},
#       'label': 'Entité Financière',
#       'type': 'text'},
#      {'name': 'type_de_mouvements',
#       'description': None,
#       'annotations': {},
#       'label': 'Type de mouvements',
#       'type': 'text'},
#      {'name': 'section',
#       'description': None,
#       'annotations': {},
#       'label': 'Section',
#       'type': 'text'},
#      {'name': 'nomenclature',
#       'description': None,
#       'annotations': {},
#       'label': 'Nomenclature',
#       'type': 'text'},
#      {'name': 'chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Chapitre',
#       'type': 'text'},
#      {'name': 'libelle_chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Chapitre',
#       'type': 'text'},
#      {'name': 'article',
#       'description': None,
#       'annotations': {},
#       'label': 'Article',
#       'type': 'text'},
#      {'name': 'libelle_article',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Article',
#       'type': 'text'},
#      {'name': 'code_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Code fonction',
#       'type': 'text'},
#      {'name': 'libelle_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé fonction',
#       'type': 'text'},
#      {'name': 'montant_realise_depense',
#       'description': None,
#       'annotations': {},
#       'label': 'Montant Réalisé Dépense',
#       'type': 'double'},
#      {'name': 'montant_realise_recette',
#       'description': None,
#       'annotations': {},
#       'label': 'Montant Réalisé Recette',
#       'type': 'double'}],
#     'metas': {'dcat': {'created': '2019-04-11',
#       'issued': '2019-04-11',
#       'creator': 'Direction des Finances Blagnac',
#       'contributor': 'DSI Blagnac',
#       'contact_name': None,
#       'contact_email': None,
#       'accrualperiodicity': 'annuelle',
#       'spatial': 'Ville de Blagnac',
#       'temporal': 'Année',
#       'granularity': 'Compte M14',
#       'dataquality': None,
#       'publisher_type': None,
#       'conforms_to': None,
#       'temporal_coverage_start': None,
#       'temporal_coverage_end': None,
#       'accessRights': None,
#       'relation': None},
#      'inspire': {'theme': None,
#       'type': None,
#       'file_identifier': None,
#       'hierarchy_level': None,
#       'hierarchy_level_name': None,
#       'spatial_resolution': None,
#       'topologic_consistency': None,
#       'contact_individual_name': None,
#       'contact_position': None,
#       'contact_address': None,
#       'contact_email': None,
#       'identification_purpose': None,
#       'extend_description': None,
#       'extend_bounding_box_westbound_longitude': None,
#       'extend_bounding_box_eastbound_longitude': None,
#       'extend_bounding_box_southbound_latitude': None,
#       'extend_bounding_box_northbound_latitude': None},
#      'default': {'title': 'Compte administratif 2015 - Blagnac',
#       'description': None,
#       'theme': ['Finance'],
#       'keyword': ['COMPTE ADMINISTRATIF', 'budget', 'finances'],
#       'license': 'Open Database License (ODbL)',
#       'license_url': 'http://opendatacommons.org/licenses/odbl/',
#       'language': 'fr',
#       'metadata_languages': ['fr'],
#       'timezone': None,
#       'modified': '2019-04-11T11:05:59+00:00',
#       'modified_updates_on_metadata_change': False,
#       'modified_updates_on_data_change': False,
#       'data_processed': '2019-04-11T13:23:27+00:00',
#       'metadata_processed': '2025-04-30T08:42:54.258000+00:00',
#       'geographic_reference': ['fr_70_243100518'],
#       'geographic_reference_auto': True,
#       'territory': ['Toulouse Métropole'],
#       'geometry_types': None,
#       'bbox': None,
#       'publisher': 'Ville de Blagnac',
#       'references': None,
#       'records_count': 1195,
#       'attributions': None,
#       'source_domain': None,
#       'source_domain_title': None,
#       'source_domain_address': None,
#       'source_dataset': None,
#       'shared_catalog': None,
#       'federated': False,
#       'parent_domain': None,
#       'update_frequency': None},
#      'custom': {'villes-concernees': ['Blagnac'],
#       'cycle': None,
#       'periodicity': None}}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/affichage-election-pres-2022'},
#     {'rel': 'datasets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'records',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/affichage-election-pres-2022/records'},
#     {'rel': 'exports',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/affichage-election-pres-2022/exports'},
#     {'rel': 'facets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/affichage-election-pres-2022/facets'},
#     {'rel': 'reuses',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/affichage-election-pres-2022/reuses'}],
#    'dataset': {'visibility': 'domain',
#     'dataset_id': 'affichage-election-pres-2022',
#     'dataset_uid': 'da_eglosy',
#     'has_records': True,
#     'features': ['geo'],
#     'attachments': [],
#     'alternative_exports': [],
#     'data_visible': True,
#     'fields': [{'name': 'geo_point_2d',
#       'description': None,
#       'annotations': {},
#       'label': 'Geo Point',
#       'type': 'geo_point_2d'},
#      {'name': 'geo_shape',
#       'description': None,
#       'annotations': {},
#       'label': 'Geo Shape',
#       'type': 'geo_shape'},
#      {'name': 'lieu_de_vote',
#       'description': None,
#       'annotations': {},
#       'label': 'lieu_de_vote',
#       'type': 'text'},
#      {'name': 'adresse',
#       'description': None,
#       'annotations': {},
#       'label': 'adresse',
#       'type': 'text'},
#      {'name': 'bureaux',
#       'description': None,
#       'annotations': {},
#       'label': 'bureaux',
#       'type': 'text'},
#      {'name': 'detail_emplacement',
#       'description': None,
#       'annotations': {},
#       'label': 'detail_emplacement',
#       'type': 'text'}],
#     'metas': {'dcat': {'created': '2013-03-12',
#       'issued': None,
#       'creator': 'Direction Mobilité Gestion Réseaux ',
#       'contributor': 'SIG Toulouse',
#       'contact_name': None,
#       'contact_email': None,
#       'accrualperiodicity': 'Hebdomadaire',
#       'spatial': None,
#       'temporal': None,
#       'granularity': None,
#       'dataquality': None,
#       'publisher_type': None,
#       'conforms_to': None,
#       'temporal_coverage_start': None,
#       'temporal_coverage_end': None,
#       'accessRights': None,
#       'relation': None},
#      'inspire': {'theme': None,
#       'type': None,
#       'file_identifier': None,
#       'hierarchy_level': None,
#       'hierarchy_level_name': None,
#       'spatial_resolution': None,
#       'topologic_consistency': None,
#       'contact_individual_name': None,
#       'contact_position': None,
#       'contact_address': None,
#       'contact_email': None,
#       'identification_purpose': None,
#       'extend_description': None,
#       'extend_bounding_box_westbound_longitude': None,
#       'extend_bounding_box_eastbound_longitude': None,
#       'extend_bounding_box_southbound_latitude': None,
#       'extend_bounding_box_northbound_latitude': None},
#      'default': {'title': 'Affichage politique - élection présidentielle 2022 - Toulouse',
#       'description': "Localisation des panneaux d'affichage politique pour l'élection présidentielle de 2022.",
#       'theme': ['Citoyenneté'],
#       'keyword': ['affichage',
#        'panneaux',
#        'citoyennete',
#        'élection',
#        '2021',
#        'présidentielle'],
#       'license': 'Open Database License (ODbL)',
#       'license_url': 'http://opendatacommons.org/licenses/odbl/',
#       'language': 'fr',
#       'metadata_languages': ['fr'],
#       'timezone': None,
#       'modified': '2022-04-05T07:26:02+00:00',
#       'modified_updates_on_metadata_change': True,
#       'modified_updates_on_data_change': False,
#       'data_processed': '2022-06-20T07:59:53+00:00',
#       'metadata_processed': '2022-06-20T07:59:53.911000+00:00',
#       'geographic_reference': ['fr_80_31555'],
#       'geographic_reference_auto': False,
#       'territory': ['Toulouse'],
#       'geometry_types': ['Point'],
#       'bbox': None,
#       'publisher': 'Toulouse Métropole',
#       'references': None,
#       'records_count': 68,
#       'attributions': None,
#       'source_domain': None,
#       'source_domain_title': None,
#       'source_domain_address': None,
#       'source_dataset': None,
#       'shared_catalog': None,
#       'federated': False,
#       'parent_domain': None,
#       'update_frequency': None},
#      'custom': {'villes-concernees': ['Toulouse'],
#       'cycle': None,
#       'periodicity': None}}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2023-ccas-blagnac'},
#     {'rel': 'datasets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'records',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2023-ccas-blagnac/records'},
#     {'rel': 'exports',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2023-ccas-blagnac/exports'},
#     {'rel': 'facets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2023-ccas-blagnac/facets'},
#     {'rel': 'reuses',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2023-ccas-blagnac/reuses'}],
#    'dataset': {'visibility': 'domain',
#     'dataset_id': 'budget-primitif-2023-ccas-blagnac',
#     'dataset_uid': 'da_odcy48',
#     'has_records': True,
#     'features': ['analyze'],
#     'attachments': [],
#     'alternative_exports': [],
#     'data_visible': True,
#     'fields': [{'name': 'exercice',
#       'description': None,
#       'annotations': {},
#       'label': 'Exercice',
#       'type': 'text'},
#      {'name': 'entite_financiere',
#       'description': None,
#       'annotations': {},
#       'label': 'Entité Financière',
#       'type': 'text'},
#      {'name': 'type_de_mouvements',
#       'description': None,
#       'annotations': {},
#       'label': 'Type de mouvements',
#       'type': 'text'},
#      {'name': 'section',
#       'description': None,
#       'annotations': {},
#       'label': 'Section',
#       'type': 'text'},
#      {'name': 'nomenclature',
#       'description': None,
#       'annotations': {},
#       'label': 'Nomenclature',
#       'type': 'text'},
#      {'name': 'chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Chapitre',
#       'type': 'int'},
#      {'name': 'libelle_chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Chapitre',
#       'type': 'text'},
#      {'name': 'article',
#       'description': None,
#       'annotations': {},
#       'label': 'Article',
#       'type': 'int'},
#      {'name': 'libelle_article',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Article',
#       'type': 'text'},
#      {'name': 'code_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Code fonction',
#       'type': 'int'},
#      {'name': 'libelle_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé fonction',
#       'type': 'text'},
#      {'name': 'mt_vote_bp_depense',
#       'description': None,
#       'annotations': {},
#       'label': 'MT Voté BP Dépense',
#       'type': 'text'},
#      {'name': 'mt_vote_bp_recette',
#       'description': None,
#       'annotations': {},
#       'label': 'MT Voté BP Recette',
#       'type': 'text'}],
#     'metas': {'dcat': {'created': None,
#       'issued': None,
#       'creator': None,
#       'contributor': None,
#       'contact_name': None,
#       'contact_email': None,
#       'accrualperiodicity': None,
#       'spatial': None,
#       'temporal': None,
#       'granularity': None,
#       'dataquality': None,
#       'publisher_type': None,
#       'conforms_to': None,
#       'temporal_coverage_start': None,
#       'temporal_coverage_end': None,
#       'accessRights': None,
#       'relation': None},
#      'inspire': {'theme': None,
#       'type': None,
#       'file_identifier': None,
#       'hierarchy_level': None,
#       'hierarchy_level_name': None,
#       'spatial_resolution': None,
#       'topologic_consistency': None,
#       'contact_individual_name': None,
#       'contact_position': None,
#       'contact_address': None,
#       'contact_email': None,
#       'identification_purpose': None,
#       'extend_description': None,
#       'extend_bounding_box_westbound_longitude': None,
#       'extend_bounding_box_eastbound_longitude': None,
#       'extend_bounding_box_southbound_latitude': None,
#       'extend_bounding_box_northbound_latitude': None},
#      'default': {'title': 'Budget Primitif 2023 - CCAS Blagnac',
#       'description': None,
#       'theme': ['Finance'],
#       'keyword': ['Blagnac', 'ccas', 'budget', 'primitif', '2023'],
#       'license': 'Open Database License (ODbL)',
#       'license_url': 'http://opendatacommons.org/licenses/odbl/',
#       'language': 'fr',
#       'metadata_languages': ['fr'],
#       'timezone': None,
#       'modified': '2025-07-29T08:07:53+00:00',
#       'modified_updates_on_metadata_change': False,
#       'modified_updates_on_data_change': False,
#       'data_processed': '2025-07-29T08:08:57+00:00',
#       'metadata_processed': '2025-07-31T13:54:54.854000+00:00',
#       'geographic_reference': None,
#       'geographic_reference_auto': False,
#       'territory': None,
#       'geometry_types': None,
#       'bbox': None,
#       'publisher': 'Ville de Blagnac',
#       'references': None,
#       'records_count': 34,
#       'attributions': None,
#       'source_domain': None,
#       'source_domain_title': None,
#       'source_domain_address': None,
#       'source_dataset': None,
#       'shared_catalog': None,
#       'federated': False,
#       'parent_domain': None,
#       'update_frequency': None},
#      'custom': {'villes-concernees': ['Blagnac'],
#       'cycle': None,
#       'periodicity': None}}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/compte-administratif-2021-regie-restauration-blagnac'},
#     {'rel': 'datasets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'records',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/compte-administratif-2021-regie-restauration-blagnac/records'},
#     {'rel': 'exports',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/compte-administratif-2021-regie-restauration-blagnac/exports'},
#     {'rel': 'facets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/compte-administratif-2021-regie-restauration-blagnac/facets'},
#     {'rel': 'reuses',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/compte-administratif-2021-regie-restauration-blagnac/reuses'}],
#    'dataset': {'visibility': 'domain',
#     'dataset_id': 'compte-administratif-2021-regie-restauration-blagnac',
#     'dataset_uid': 'da_ckguhq',
#     'has_records': True,
#     'features': ['analyze'],
#     'attachments': [],
#     'alternative_exports': [],
#     'data_visible': True,
#     'fields': [{'name': 'exercice',
#       'description': None,
#       'annotations': {},
#       'label': 'Exercice',
#       'type': 'text'},
#      {'name': 'entite_financiere',
#       'description': None,
#       'annotations': {},
#       'label': 'Entité Financière',
#       'type': 'text'},
#      {'name': 'type_de_mouvements',
#       'description': None,
#       'annotations': {},
#       'label': 'Type de mouvements',
#       'type': 'text'},
#      {'name': 'section',
#       'description': None,
#       'annotations': {},
#       'label': 'Section',
#       'type': 'text'},
#      {'name': 'nomenclature',
#       'description': None,
#       'annotations': {},
#       'label': 'Nomenclature',
#       'type': 'text'},
#      {'name': 'chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Chapitre',
#       'type': 'int'},
#      {'name': 'libelle_chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Chapitre',
#       'type': 'text'},
#      {'name': 'article',
#       'description': None,
#       'annotations': {},
#       'label': 'Article',
#       'type': 'int'},
#      {'name': 'libelle_article',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Article',
#       'type': 'text'},
#      {'name': 'code_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Code fonction',
#       'type': 'int'},
#      {'name': 'libelle_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé fonction',
#       'type': 'text'},
#      {'name': 'montant_realise_depense',
#       'description': None,
#       'annotations': {},
#       'label': 'Montant Réalisé Dépense',
#       'type': 'text'},
#      {'name': 'montant_realise_recette',
#       'description': None,
#       'annotations': {},
#       'label': 'Montant Réalisé Recette',
#       'type': 'text'}],
#     'metas': {'dcat': {'created': None,
#       'issued': None,
#       'creator': None,
#       'contributor': None,
#       'contact_name': None,
#       'contact_email': None,
#       'accrualperiodicity': None,
#       'spatial': None,
#       'temporal': None,
#       'granularity': None,
#       'dataquality': None,
#       'publisher_type': None,
#       'conforms_to': None,
#       'temporal_coverage_start': None,
#       'temporal_coverage_end': None,
#       'accessRights': None,
#       'relation': None},
#      'inspire': {'theme': None,
#       'type': None,
#       'file_identifier': None,
#       'hierarchy_level': None,
#       'hierarchy_level_name': None,
#       'spatial_resolution': None,
#       'topologic_consistency': None,
#       'contact_individual_name': None,
#       'contact_position': None,
#       'contact_address': None,
#       'contact_email': None,
#       'identification_purpose': None,
#       'extend_description': None,
#       'extend_bounding_box_westbound_longitude': None,
#       'extend_bounding_box_eastbound_longitude': None,
#       'extend_bounding_box_southbound_latitude': None,
#       'extend_bounding_box_northbound_latitude': None},
#      'default': {'title': 'Compte Administratif 2021 - Régie Restauration Blagnac',
#       'description': None,
#       'theme': ['Finance'],
#       'keyword': ['CA',
#        'cantine',
#        'RMR',
#        '2021',
#        'restauration',
#        'primitif',
#        'COMPTE ADMINISTRATIF',
#        'Blagnac'],
#       'license': 'Open Database License (ODbL)',
#       'license_url': 'http://opendatacommons.org/licenses/odbl/',
#       'language': 'fr',
#       'metadata_languages': ['fr'],
#       'timezone': None,
#       'modified': '2025-07-29T07:57:04+00:00',
#       'modified_updates_on_metadata_change': False,
#       'modified_updates_on_data_change': False,
#       'data_processed': '2025-07-29T07:59:00+00:00',
#       'metadata_processed': '2025-07-31T13:57:16.392000+00:00',
#       'geographic_reference': None,
#       'geographic_reference_auto': False,
#       'territory': None,
#       'geometry_types': None,
#       'bbox': None,
#       'publisher': 'Ville de Blagnac',
#       'references': None,
#       'records_count': 56,
#       'attributions': None,
#       'source_domain': None,
#       'source_domain_title': None,
#       'source_domain_address': None,
#       'source_dataset': None,
#       'shared_catalog': None,
#       'federated': False,
#       'parent_domain': None,
#       'update_frequency': None},
#      'custom': {'villes-concernees': ['Blagnac'],
#       'cycle': None,
#       'periodicity': None}}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2014-aeroscopia-blagnac'},
#     {'rel': 'datasets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'records',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2014-aeroscopia-blagnac/records'},
#     {'rel': 'exports',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2014-aeroscopia-blagnac/exports'},
#     {'rel': 'facets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2014-aeroscopia-blagnac/facets'},
#     {'rel': 'reuses',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budget-primitif-2014-aeroscopia-blagnac/reuses'}],
#    'dataset': {'visibility': 'domain',
#     'dataset_id': 'budget-primitif-2014-aeroscopia-blagnac',
#     'dataset_uid': 'da_brajma',
#     'has_records': True,
#     'features': ['analyze'],
#     'attachments': [],
#     'alternative_exports': [],
#     'data_visible': True,
#     'fields': [{'name': 'exercice',
#       'description': None,
#       'annotations': {},
#       'label': 'Exercice',
#       'type': 'double'},
#      {'name': 'entite_financiere',
#       'description': None,
#       'annotations': {},
#       'label': 'Entité Financière',
#       'type': 'text'},
#      {'name': 'type_de_mouvements',
#       'description': None,
#       'annotations': {},
#       'label': 'Type de mouvements',
#       'type': 'text'},
#      {'name': 'section',
#       'description': None,
#       'annotations': {},
#       'label': 'Section',
#       'type': 'text'},
#      {'name': 'nomenclature',
#       'description': None,
#       'annotations': {},
#       'label': 'Nomenclature',
#       'type': 'text'},
#      {'name': 'chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Chapitre',
#       'type': 'text'},
#      {'name': 'libelle_chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Chapitre',
#       'type': 'text'},
#      {'name': 'article',
#       'description': None,
#       'annotations': {},
#       'label': 'Article',
#       'type': 'text'},
#      {'name': 'libelle_article',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Article',
#       'type': 'text'},
#      {'name': 'code_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Code fonction',
#       'type': 'text'},
#      {'name': 'libelle_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé fonction',
#       'type': 'text'},
#      {'name': 'mt_vote_bp_depense',
#       'description': None,
#       'annotations': {},
#       'label': 'MT Voté BP Dépense',
#       'type': 'double'},
#      {'name': 'mt_vote_bp_recette',
#       'description': None,
#       'annotations': {},
#       'label': 'MT Voté BP Recette',
#       'type': 'double'}],
#     'metas': {'dcat': {'created': '2019-04-12',
#       'issued': '2019-04-12',
#       'creator': 'Direction des Finances Blagnac',
#       'contributor': 'DSI Blagnac',
#       'contact_name': None,
#       'contact_email': None,
#       'accrualperiodicity': 'annuelle',
#       'spatial': 'Ville de Blagnac',
#       'temporal': 'Année',
#       'granularity': 'Compte M14',
#       'dataquality': None,
#       'publisher_type': None,
#       'conforms_to': None,
#       'temporal_coverage_start': None,
#       'temporal_coverage_end': None,
#       'accessRights': None,
#       'relation': None},
#      'inspire': {'theme': None,
#       'type': None,
#       'file_identifier': None,
#       'hierarchy_level': None,
#       'hierarchy_level_name': None,
#       'spatial_resolution': None,
#       'topologic_consistency': None,
#       'contact_individual_name': None,
#       'contact_position': None,
#       'contact_address': None,
#       'contact_email': None,
#       'identification_purpose': None,
#       'extend_description': None,
#       'extend_bounding_box_westbound_longitude': None,
#       'extend_bounding_box_eastbound_longitude': None,
#       'extend_bounding_box_southbound_latitude': None,
#       'extend_bounding_box_northbound_latitude': None},
#      'default': {'title': 'Budget primitif 2014 - Aéroscopia Blagnac',
#       'description': None,
#       'theme': ['Finance'],
#       'keyword': ['aéroscopia',
#        'aéronautique',
#        'budget',
#        'budget primitif',
#        'primitif',
#        'finances'],
#       'license': 'Open Database License (ODbL)',
#       'license_url': 'http://opendatacommons.org/licenses/odbl/',
#       'language': 'fr',
#       'metadata_languages': ['fr'],
#       'timezone': None,
#       'modified': '2019-04-12T07:13:55+00:00',
#       'modified_updates_on_metadata_change': False,
#       'modified_updates_on_data_change': False,
#       'data_processed': '2019-04-12T07:16:40+00:00',
#       'metadata_processed': '2025-04-30T08:38:47.278000+00:00',
#       'geographic_reference': ['fr_70_243100518'],
#       'geographic_reference_auto': True,
#       'territory': ['Toulouse Métropole'],
#       'geometry_types': None,
#       'bbox': None,
#       'publisher': 'Ville de Blagnac',
#       'references': None,
#       'records_count': 8,
#       'attributions': None,
#       'source_domain': None,
#       'source_domain_title': None,
#       'source_domain_address': None,
#       'source_dataset': None,
#       'shared_catalog': None,
#       'federated': False,
#       'parent_domain': None,
#       'update_frequency': None},
#      'custom': {'villes-concernees': ['Blagnac'],
#       'cycle': None,
#       'periodicity': None}}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budgetprimitif-vote-2018'},
#     {'rel': 'datasets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'records',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budgetprimitif-vote-2018/records'},
#     {'rel': 'exports',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budgetprimitif-vote-2018/exports'},
#     {'rel': 'facets',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budgetprimitif-vote-2018/facets'},
#     {'rel': 'reuses',
#      'href': 'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/budgetprimitif-vote-2018/reuses'}],
#    'dataset': {'visibility': 'domain',
#     'dataset_id': 'budgetprimitif-vote-2018',
#     'dataset_uid': 'da_sks6je',
#     'has_records': True,
#     'features': ['analyze'],
#     'attachments': [],
#     'alternative_exports': [],
#     'data_visible': True,
#     'fields': [{'name': 'exercice',
#       'description': None,
#       'annotations': {},
#       'label': 'Exercice',
#       'type': 'double'},
#      {'name': 'entite_financiere',
#       'description': None,
#       'annotations': {},
#       'label': 'Entité Financière',
#       'type': 'text'},
#      {'name': 'type_de_mouvements',
#       'description': None,
#       'annotations': {},
#       'label': 'Type de mouvements',
#       'type': 'text'},
#      {'name': 'section',
#       'description': None,
#       'annotations': {},
#       'label': 'Section',
#       'type': 'text'},
#      {'name': 'nomenclature',
#       'description': None,
#       'annotations': {},
#       'label': 'Nomenclature',
#       'type': 'text'},
#      {'name': 'chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Chapitre',
#       'type': 'text'},
#      {'name': 'libelle_chapitre',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Chapitre',
#       'type': 'text'},
#      {'name': 'article',
#       'description': None,
#       'annotations': {},
#       'label': 'Article',
#       'type': 'text'},
#      {'name': 'libelle_article',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé Article',
#       'type': 'text'},
#      {'name': 'code_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Code fonction',
#       'type': 'text'},
#      {'name': 'libelle_fonction',
#       'description': None,
#       'annotations': {},
#       'label': 'Libellé fonction',
#       'type': 'text'},
#      {'name': 'mt_vote_bp_depense',
#       'description': None,
#       'annotations': {},
#       'label': 'MT Voté BP Dépense',
#       'type': 'double'},
#      {'name': 'mt_vote_bp_recette',
#       'description': None,
#       'annotations': {},
#       'label': 'MT Voté BP Recette',
#       'type': 'double'}],
#     'metas': {'dcat': {'created': '2019-04-11',
#       'issued': None,
#       'creator': 'Direction des Finances Blagnac',
#       'contributor': 'DSI Blagnac',
#       'contact_name': None,
#       'contact_email': None,
#       'accrualperiodicity': 'annuelle',
#       'spatial': 'Ville de Blagnac',
#       'temporal': 'Année',
#       'granularity': 'Compte M14',
#       'dataquality': None,
#       'publisher_type': None,
#       'conforms_to': None,
#       'temporal_coverage_start': None,
#       'temporal_coverage_end': None,
#       'accessRights': None,
#       'relation': None},
#      'inspire': {'theme': None,
#       'type': None,
#       'file_identifier': None,
#       'hierarchy_level': None,
#       'hierarchy_level_name': None,
#       'spatial_resolution': None,
#       'topologic_consistency': None,
#       'contact_individual_name': None,
#       'contact_position': None,
#       'contact_address': None,
#       'contact_email': None,
#       'identification_purpose': None,
#       'extend_description': None,
#       'extend_bounding_box_westbound_longitude': None,
#       'extend_bounding_box_eastbound_longitude': None,
#       'extend_bounding_box_southbound_latitude': None,
#       'extend_bounding_box_northbound_latitude': None},
#      'default': {'title': 'Budget primitif 2018 - Blagnac',
#       'description': None,
#       'theme': ['Finance'],
#       'keyword': ['budget', 'budget primitif', 'primitif', 'finances'],
#       'license': 'Open Database License (ODbL)',
#       'license_url': 'http://opendatacommons.org/licenses/odbl/',
#       'language': 'fr',
#       'metadata_languages': ['fr'],
#       'timezone': None,
#       'modified': '2019-04-11T10:32:25+00:00',
#       'modified_updates_on_metadata_change': False,
#       'modified_updates_on_data_change': False,
#       'data_processed': '2019-04-11T12:39:58+00:00',
#       'metadata_processed': '2025-04-30T08:43:57.513000+00:00',
#       'geographic_reference': ['fr_70_243100518'],
#       'geographic_reference_auto': True,
#       'territory': ['Toulouse Métropole'],
#       'geometry_types': None,
#       'bbox': None,
#       'publisher': 'Ville de Blagnac',
#       'references': None,
#       'records_count': 1114,
#       'attributions': None,
#       'source_domain': None,
#       'source_domain_title': None,
#       'source_domain_address': None,
#       'source_dataset': None,
#       'shared_catalog': None,
#       'federated': False,
#       'parent_domain': None,
#       'update_frequency': None},
#      'custom': {'villes-concernees': ['Blagnac'],
#       'cycle': None,
#       'periodicity': None}}}}]}

# %%
'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets'

'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/records'

'https://data.toulouse-metropole.fr/api/explore/v2.0/catalog/datasets/api-velo-toulouse-temps-reel/records'

# %%
df.results
# Out:
# 0     {'number': 408, 'name': '00408 - BRUNAUD - CEA...
# 1     {'number': 253, 'name': '00253 - ÉTATS-UNIS - ...
# 2     {'number': 412, 'name': '00412 - PARC DE LA PO...
# 3     {'number': 2009, 'name': '02009 - PLACE DU REL...
# 4     {'number': 5004, 'name': '05004 - POMPIDOU - M...
# 5     {'number': 2011, 'name': '02011 - PATINOIRE BA...
# 6     {'number': 2004, 'name': '02004 - GRENADE - GA...
# 7     {'number': 261, 'name': '00261 - VAN DYCK - RA...
# 8     {'number': 403, 'name': '00403 - NARBONNE - CL...
# 9     {'number': 2003, 'name': '02003 - SERVANTY AIR...
# 10    {'number': 273, 'name': '00273 - PASSERIEU - R...
# 11    {'number': 1032, 'name': '1032 -  BORNE CGB AT...
# 12    {'number': 195, 'name': '00195 - RIEUX - CHANT...
# 13    {'number': 339, 'name': '00339 -  GLOIRE - SAV...
# 14    {'number': 65, 'name': '00065 - VERDIER - GRAN...
# 15    {'number': 22, 'name': '00022 - CARNOT - ROLAN...
# 16    {'number': 236, 'name': '00236 - TOEC - LEMIRE...
# 17    {'number': 152, 'name': '00152 - THÉATRE DES M...
# 18    {'number': 384, 'name': '00384 GUILHERMY - LAS...
# 19    {'number': 174, 'name': '00174 - BOURGES - MAU...
# Name: results, dtype: object
